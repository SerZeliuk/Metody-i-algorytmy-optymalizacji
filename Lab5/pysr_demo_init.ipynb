# %% [markdown]
# # Setup

# %% [markdown]
# ## Instructions
# 1. Work on a copy of this notebook: _File_ > _Save a copy in Drive_ (you will need a Google account).
# 2. (Optional) If you would like to do the deep learning component of this tutorial, turn on the GPU with Edit->Notebook settings->Hardware accelerator->GPU

# %%
# !pip install -U pysr
# Out:
# Requirement already satisfied: pysr in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (1.5.6)
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: sympy<2.0.0,>=1.0.0 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from pysr) (1.14.0)
# Requirement already satisfied: pandas<3.0.0,>=0.21.0 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from pysr) (2.2.1)
# Requirement already satisfied: numpy<3.0.0,>=1.13.0 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from pysr) (1.26.4)
# Requirement already satisfied: scikit_learn<2.0.0,>=1.0.0 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from pysr) (1.5.0)
# Requirement already satisfied: juliacall==0.9.24 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from pysr) (0.9.24)
# Requirement already satisfied: click<9.0.0,>=7.0.0 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from pysr) (8.1.7)
# Requirement already satisfied: setuptools>=50.0.0 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from pysr) (69.0.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.0.0 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from pysr) (4.13.2)
# Requirement already satisfied: juliapkg~=0.1.8 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from juliacall==0.9.24->pysr) (0.1.16)
# Requirement already satisfied: colorama in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from click<9.0.0,>=7.0.0->pysr) (0.4.6)
# Requirement already satisfied: filelock<4.0,>=3.16 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from juliapkg~=0.1.8->juliacall==0.9.24->pysr) (3.18.0)
# Requirement already satisfied: semver<4.0,>=3.0 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from juliapkg~=0.1.8->juliacall==0.9.24->pysr) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from pandas<3.0.0,>=0.21.0->pysr) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from pandas<3.0.0,>=0.21.0->pysr) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from pandas<3.0.0,>=0.21.0->pysr) (2024.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from scikit_learn<2.0.0,>=1.0.0->pysr) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from scikit_learn<2.0.0,>=1.0.0->pysr) (1.3.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from scikit_learn<2.0.0,>=1.0.0->pysr) (3.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from sympy<2.0.0,>=1.0.0->pysr) (1.3.0)
# Requirement already satisfied: six>=1.5 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=0.21.0->pysr) (1.16.0)

# %% [markdown]
# Julia and Julia dependencies are installed at first import:

# %%
import pysr
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %% [markdown]
# Now, let's import everything else as well as the PySRRegressor:

# %%
import sympy
import numpy as np
from matplotlib import pyplot as plt
from pysr import PySRRegressor
from sklearn.model_selection import train_test_split
# Out:
# [IPKernelApp] ERROR | Error in message handler
# Traceback (most recent call last):
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 393, in dispatch_shell
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\jupyter_client\session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list

# %% [markdown]
# # Simple PySR example:

# %% [markdown]
# First, let's learn a simple function
#
# $$2.5382 \cos(x3) + x0^2 - 2$$

# %%
# Dataset
np.random.seed(0)
X = 2 * np.random.randn(100, 5)
y = 2.5382 * np.cos(X[:, 3]) + X[:, 0] ** 2 - 2

# %% [markdown]
# By default, we will set up 30 populations of expressions (which evolve independently except for migrations), use 4 threads, and use `"best"` for our model selection strategy:

# %%
default_pysr_params = dict(
    populations=30,
    model_selection="best",
)

# %% [markdown]
# PySR can run for arbitrarily long, and continue to find more and more accurate expressions. You can set the total number of cycles of evolution with `niterations`, although there are also a [few more ways](https://github.com/MilesCranmer/PySR/pull/134) to stop execution.
#
# **This first execution will take a bit longer to startup, as the library is JIT-compiled. The next execution will be much faster.**

# %%
# Learn equations
model = PySRRegressor(
    niterations=30,
    binary_operators=["+", "*"],
    unary_operators=["cos", "exp", "sin"],
    **default_pysr_params,
)

model.fit(X, y)
# Out:
# c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\pysr\sr.py:2776: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Compiling Julia backend...
# [ Info: Started!
# [ Info: Final population:
# [ Info: Results saved to:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           3.360e+01  1.594e+01  y = 2.3551
# 3           6.128e+00  8.509e-01  y = x₀ * x₀
# 5           3.045e+00  3.496e-01  y = (x₀ * x₀) + -1.7559
# 7           3.030e+00  2.620e-03  y = (x₀ * (x₀ * 0.97769)) + -1.664
# 8           1.118e+00  9.964e-01  y = ((x₀ * x₀) + cos(x₃)) + -1.852
# 10          2.217e-13  7.971e+00  y = (x₀ * x₀) + ((cos(x₃) * 2.5382) + -2)
# 12          1.941e-13  6.653e-02  y = (((cos(x₃) * 2.5382) + -0.84966) + (x₀ * x₀)) + -1.150...
#                                       3
# 14          1.828e-13  3.012e-02  y = (((cos(x₃) * 2.5382) + -0.84966) + ((x₀ * x₀) + 0.3634...
#                                       7)) + -1.5138
# 17          1.564e-13  5.198e-02  y = (exp(x₀) * 7.8238e-09) + ((((cos(x₃) * 2.5382) + -0.84...
#                                       966) + (x₀ * x₀)) + -1.1503)
# 19          1.467e-13  3.212e-02  y = ((((cos(x₃) * 2.5382) + -0.84966) + ((x₀ * x₀) + 0.363...
#                                       47)) + -1.5138) + (exp(x₀) * 7.8238e-09)
# 20          1.214e-13  1.888e-01  y = ((exp(cos(x₄ * -0.77126) * x₀) * 2.4331e-08) + ((x₀ * ...
#                                       x₀) + -2)) + (cos(x₃) * 2.5382)
# 25          1.147e-13  1.142e-02  y = ((((cos(x₃) * 2.5382) + -0.84966) + ((x₀ * x₀) + 0.363...
#                                       47)) + -1.5138) + (exp((x₀ + (x₄ * -0.42713)) * -0.74767) ...
#                                       * 1.1951e-08)
# 26          1.125e-13  1.942e-02  y = (((exp(sin(cos(cos(x₄)))) * (exp(cos(-0.77126 * x₄) * ...
#                                       x₀) * 1.2973e-08)) + -2) + (x₀ * x₀)) + (cos(x₃) * 2.5382)
# 27          1.024e-13  9.399e-02  y = ((exp(cos(sin(x₁))) * (exp(cos((-0.77126 * x₄) + 0.281...
#                                       07) * x₀) * 1.2973e-08)) + (-2 + (x₀ * x₀))) + (cos(x₃) * ...
#                                       2.5382)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
#   - outputs\20250510_145958_6ScttX\hall_of_fame.csv
# PySRRegressor.equations_ = [
# 	    pick      score                                           equation  \
# 	0          0.000000                                          2.3550603
# 	1          0.850855                                            x0 * x0
# 	2          0.349618                              (x0 * x0) + -1.755881
# 	3          0.002620                 (x0 * (x0 * 0.97769)) + -1.6640385
# 	4          0.996444                 ((x0 * x0) + cos(x3)) + -1.8519864
# 	5         14.624605      (x0 * x0) + ((cos(x3) * 2.5382) + -1.9999999)
# 	6          0.066534  (((cos(x3) * 2.5382001) + -0.84966445) + (x0 *...
# 	7          0.030115  (((cos(x3) * 2.5382001) + -0.84966445) + ((x0 ...
# 	8          0.051983  (exp(x0) * 7.823759e-9) + ((((cos(x3) * 2.5382...
# 	9          0.032120  ((((cos(x3) * 2.5382001) + -0.84966445) + ((x0...
# 	10  >>>>   0.188837  ((exp(cos(x4 * -0.77125883) * x0) * 2.4330557e...
# 	11         0.011420  ((((cos(x3) * 2.5382001) + -0.84966445) + ((x0...
# 	12         0.019418  (((exp(sin(cos(cos(x4)))) * (exp(cos(-0.771258...
# 	13         0.093991  ((exp(cos(sin(x1))) * (exp(cos((-0.77125883 * ...
#
# 	            loss  complexity
# 	0   3.360272e+01           1
# 	1   6.128180e+00           3
# 	2   3.045492e+00           5
# 	3   3.029573e+00           7
# 	4   1.118488e+00           8
# 	5   2.217485e-13          10
# 	6   1.941198e-13          12
# 	7   1.827730e-13          14
# 	8   1.563809e-13          17
# 	9   1.466509e-13          19
# 	10  1.214154e-13          20
# 	11  1.146767e-13          25
# 	12  1.124715e-13          26
# 	13  1.023817e-13          27
# ]

# %% [markdown]
# We can print the model, which will print out all the discovered expressions:

# %%
model
# Out:
# PySRRegressor.equations_ = [
# 	    pick      score                                           equation  \
# 	0          0.000000                                          2.3550603
# 	1          0.850855                                            x0 * x0
# 	2          0.349618                              (x0 * x0) + -1.755881
# 	3          0.002620                 (x0 * (x0 * 0.97769)) + -1.6640385
# 	4          0.996444                 ((x0 * x0) + cos(x3)) + -1.8519864
# 	5         14.624605      (x0 * x0) + ((cos(x3) * 2.5382) + -1.9999999)
# 	6          0.066534  (((cos(x3) * 2.5382001) + -0.84966445) + (x0 *...
# 	7          0.030115  (((cos(x3) * 2.5382001) + -0.84966445) + ((x0 ...
# 	8          0.051983  (exp(x0) * 7.823759e-9) + ((((cos(x3) * 2.5382...
# 	9          0.032120  ((((cos(x3) * 2.5382001) + -0.84966445) + ((x0...
# 	10  >>>>   0.188837  ((exp(cos(x4 * -0.77125883) * x0) * 2.4330557e...
# 	11         0.011420  ((((cos(x3) * 2.5382001) + -0.84966445) + ((x0...
# 	12         0.019418  (((exp(sin(cos(cos(x4)))) * (exp(cos(-0.771258...
# 	13         0.093991  ((exp(cos(sin(x1))) * (exp(cos((-0.77125883 * ...
#
# 	            loss  complexity
# 	0   3.360272e+01           1
# 	1   6.128180e+00           3
# 	2   3.045492e+00           5
# 	3   3.029573e+00           7
# 	4   1.118488e+00           8
# 	5   2.217485e-13          10
# 	6   1.941198e-13          12
# 	7   1.827730e-13          14
# 	8   1.563809e-13          17
# 	9   1.466509e-13          19
# 	10  1.214154e-13          20
# 	11  1.146767e-13          25
# 	12  1.124715e-13          26
# 	13  1.023817e-13          27
# ]
# [IPKernelApp] ERROR | Error in message handler
# Traceback (most recent call last):
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 393, in dispatch_shell
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\jupyter_client\session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# [IPKernelApp] ERROR | Error in message handler
# Traceback (most recent call last):
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 393, in dispatch_shell
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\jupyter_client\session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# [IPKernelApp] ERROR | Error in message handler
# Traceback (most recent call last):
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 393, in dispatch_shell
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\jupyter_client\session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list

# %% [markdown]
# We can also view the SymPy format of the best expression:

# %%
model.sympy()
# Out:
# x0*x0 + exp(x0*cos(x4*(-0.77125883)))*2.4330557e-8 + cos(x3)*2.5382 - 2.0

# %% [markdown]
# We can also view the SymPy of any other expression in the list, using the index of it in `model.equations_`.

# %%
model.sympy(2)
# Out:
# x0*x0 - 1.755881

# %% [markdown]
# ## Output

# %% [markdown]
# `model.equations_` is a Pandas DataFrame. We can export the results in various ways:

# %%
model.latex()
# Out:
# 'x_{0} x_{0} + e^{x_{0} \\cos{\\left(x_{4} \\left(-0.771\\right) \\right)}} 2.43 \\cdot 10^{-8} + \\cos{\\left(x_{3} \\right)} 2.54 - 2.00'

# %% [markdown]
# These is also `model.sympy(), model.jax(), model.pytorch()`. All of these can take an index as input, to get the result for an arbitrary equation in the list.
#
# We can also use `model.predict` for arbitrary equations, with the default equation being the one chosen by `model_selection`:

# %%
ypredict = model.predict(X)
ypredict_simpler = model.predict(X, 2)

print("Default selection MSE:", np.power(ypredict - y, 2).mean())
print("Manual selection MSE for index 2:", np.power(ypredict_simpler - y, 2).mean())
# Out:
# Default selection MSE: 1.6727219085125958e-13
# Manual selection MSE for index 2: 3.045492028871138

# %% [markdown]
# # Custom operators

# %% [markdown]
# A full list of operators is given here: https://astroautomata.com/PySR/operators,
# but we can also use any binary or unary operator in `julia`, or define our own as arbitrary functions.
#
# Say that we want a command to do quartic powers:
#
# $$ y = x_0^4 - 2 $$

# %%
y = X[:, 0] ** 4 - 2

# %% [markdown]
# We can do this by passing a string in Julia syntax.
#
# We also define the operator in sympy, with `extra_sympy_mappings`, to enable its use in `predict`, and other export functions.

# %%
model = PySRRegressor(
    niterations=5,
    populations=40,
    binary_operators=["+", "*"],
    unary_operators=["cos", "exp", "sin", "quart(x) = x^4"],
    extra_sympy_mappings={"quart": lambda x: x**4},
)
model.fit(X, y)
# Out:
# c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\pysr\sr.py:2776: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.590e+04  1.594e+01  y = 46.891
# 2           4.000e+00  8.288e+00  y = quart(x₀)
# 4           9.286e-11  7.971e+00  y = quart(x₀) + -2
# 9           9.239e-11  1.014e-03  y = (quart(x₀) + -2.0856) + quart(cos(cos(0.040066)))
# 14          7.409e-11  4.415e-02  y = (((x₂ + 1.4256) * (x₄ * 4.2605e-09)) + 1) * (quart(x₀)...
#                                        + -2)
# 18          7.249e-11  5.459e-03  y = (quart(x₀) * (((x₂ + 1.4256) * ((x₁ * (x₄ + 1)) * 4.26...
#                                       05e-09)) + 1)) + -2
# 20          3.713e-11  3.346e-01  y = (quart(x₀) * ((((x₂ + 1.4256) * (x₁ * ((x₁ * -0.55567)...
#                                        + x₄))) * 4.2605e-09) + 1)) + -2
# [ Info: Started!
# [ Info: Final population:
# [ Info: Results saved to:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
#   - outputs\20250510_150012_blYQfM\hall_of_fame.csv
# PySRRegressor.equations_ = [
# 	   pick      score                                           equation  \
# 	0         0.000000                                           46.89096
# 	1         8.288017                                          quart(x0)
# 	2        12.243090                             quart(x0) + -1.9999987
# 	3         0.001014  (quart(x0) + -2.0856469) + quart(cos(cos(0.040...
# 	4         0.044146  (((x2 + 1.425552) * (x4 * 4.2604906e-9)) + 1.0...
# 	5         0.005459  (quart(x0) * (((x2 + 1.425552) * ((x1 * (x4 + ...
# 	6  >>>>   0.334592  (quart(x0) * ((((x2 + 1.425552) * (x1 * ((x1 *...
#
# 	           loss  complexity
# 	0  1.590376e+04           1
# 	1  3.999999e+00           2
# 	2  9.286385e-11           4
# 	3  9.239411e-11           9
# 	4  7.409404e-11          14
# 	5  7.249377e-11          18
# 	6  3.712594e-11          20
# ]

# %%
model.sympy()
# Out:
# x0**4*((x2 + 1.425552)*x1*(x1*(-0.5556719) + x4)*4.2604906e-9 + 1.0) - 1.9999993

# %% [markdown]
# Since `quart` is arguably more complex than the other operators, you can also give it a different complexity, using, e.g., `complexity_of_operators={"quart": 2}` to give it a complexity of 2 (instead of the default 2). You can also define custom complexities for variables and constants (`complexity_of_variables` and `complexity_of_constants`, respectively - both take a single number).
#
#
# One can also add a binary operator, with, e.g., `"myoperator(x, y) = x^2 * y"`. All Julia operators that work on scalar 32-bit floating point values are available.
#
# Make sure that any operator you add is valid over the real line. So, e.g., you will need to define `"mysqrt(x) = sqrt(abs(x))"` to enable it for negative numbers,
# or, simply have it return a very large number for bad inputs (to prevent negative input in a soft way):
# `"mysqrt(x::T) where {T} = (x >= 0) ? x : T(-1e9)"` (Julia syntax for a template function of input type `T`), which will make `mysqrt(x)` return -10^9 for negative x–hurting the loss of the equation.

# %% [markdown]
# ## Scoring

# %% [markdown]
# Using `model_selection="best"`selects the equation with the max score and prints it. But in practice it is best to look through all the equations manually, select an equation above some MSE threshold, and then use the score to select among that loss threshold.
#
# Here, "score" is defined by:
# $$ \text{score} = - \log(\text{loss}_i/\text{loss}_{i-1})/
# (\text{complexity}_i - \text{complexity}_{i-1})$$

# %% [markdown]
# This scoring is motivated by the common strategy of looking for drops in the loss-complexity curve.
#
# From Schmidt & Lipson (2009) -

# %% [markdown]
# ![F4.large.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Noise example

# %% [markdown]
# Here is an example with noise. Known Gaussian noise with $\sigma$ between 0.1 and 5.0. We record samples of $y$:
#
# $$ \sigma \sim U(0.1, 5.0) $$
# $$ \epsilon \sim \mathcal{N}(0, \sigma^2)$$
# $$ y = 5\;\cos(3.5 x_0) - 1.3 + \epsilon.$$
# We have 5 features, say. The weights change the loss function to be:
# $$MSE = \sum [(y - f(x))^2*w],$$
#
# so in this example, we can set:
# $$w = 1/\sigma^2.$$

# %%
np.random.seed(0)
N = 3000
upper_sigma = 5
X = 2 * np.random.rand(N, 5)
sigma = np.random.rand(N) * (5 - 0.1) + 0.1
eps = sigma * np.random.randn(N)
y = 5 * np.cos(3.5 * X[:, 0]) - 1.3 + eps

# %% [markdown]
# Let's look at this dataset:

# %%
plt.scatter(X[:, 0], y, alpha=0.2)
plt.xlabel("$x_0$")
plt.ylabel("$y$")
# Out:
# Text(0, 0.5, '$y$')

# %% [markdown]
# Define some weights to use:

# %%
weights = 1 / sigma**2

# %%
weights[:5]
# Out:
# array([0.25199296, 0.0775419 , 0.11515701, 0.1781281 , 0.0448131 ])

# %% [markdown]
# Let's run PySR again:

# %%
model = PySRRegressor(
    elementwise_loss="myloss(x, y, w) = w * abs(x - y)",  # Custom loss function with weights.
    niterations=20,
    populations=20,  # Use more populations
    binary_operators=["+", "*"],
    unary_operators=["cos"],
)
model.fit(X, y, weights=weights)
# Out:
# c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\pysr\sr.py:2776: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# Expressions evaluated per second: 5.070e+04
# Progress: 278 / 400 total iterations (69.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           3.304e+00  1.594e+01  y = -1.1849
# 3           3.183e+00  1.860e-02  y = x₀ + -2.0872
# 4           2.755e+00  1.447e-01  y = cos(x₀) * -6.0239
# 6           1.089e+00  4.638e-01  y = cos(x₀ * 3.2908) * 4.9785
# 8           3.128e-01  6.239e-01  y = (cos(x₀ * 3.4934) * 5.022) + -1.2893
# 10          3.126e-01  3.307e-04  y = (cos((x₀ * 2.4955) + x₀) * 5.0323) + -1.2861
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           3.304e+00  1.594e+01  y = -1.1849
# 3           3.183e+00  1.860e-02  y = x₀ + -2.0872
# 4           2.743e+00  1.488e-01  y = cos(x₀ * 3.3335)
# 6           1.089e+00  4.618e-01  y = cos(x₀ * 3.2908) * 4.9785
# 8           3.128e-01  6.239e-01  y = (cos(x₀ * 3.4934) * 5.022) + -1.2893
# 10          3.126e-01  3.307e-04  y = (cos((x₀ * 2.4955) + x₀) * 5.0323) + -1.2861
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# [ Info: Final population:
# [ Info: Results saved to:
# PySRRegressor.equations_ = [
# 	   pick     score                                           equation  \
# 	0        0.000000                                          -1.184878
# 	1        0.018599                                     x0 + -2.087181
# 	2        0.148812                                cos(x0 * 3.3334649)
# 	3        0.461786                     cos(x0 * 3.2907822) * 4.978535
# 	4  >>>>  0.623871     (cos(x0 * 3.4933712) * 5.0220137) + -1.2892635
# 	5        0.000331  (cos((x0 * 2.4954913) + x0) * 5.0322843) + -1....
#
# 	       loss  complexity
# 	0  3.304065           1
# 	1  3.183420           3
# 	2  2.743251           4
# 	3  1.089339           6
# 	4  0.312806           8
# 	5  0.312600          10
# ]
#   - outputs\20250510_150015_ymWM8d\hall_of_fame.csv

# %% [markdown]
# Let's see if we get similar results to the true equation

# %%
model
# Out:
# PySRRegressor.equations_ = [
# 	   pick     score                                           equation  \
# 	0        0.000000                                          -1.184878
# 	1        0.018599                                     x0 + -2.087181
# 	2        0.148812                                cos(x0 * 3.3334649)
# 	3        0.461786                     cos(x0 * 3.2907822) * 4.978535
# 	4  >>>>  0.623871     (cos(x0 * 3.4933712) * 5.0220137) + -1.2892635
# 	5        0.000331  (cos((x0 * 2.4954913) + x0) * 5.0322843) + -1....
#
# 	       loss  complexity
# 	0  3.304065           1
# 	1  3.183420           3
# 	2  2.743251           4
# 	3  1.089339           6
# 	4  0.312806           8
# 	5  0.312600          10
# ]
# [IPKernelApp] ERROR | Error in message handler
# Traceback (most recent call last):
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 393, in dispatch_shell
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\jupyter_client\session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# [IPKernelApp] ERROR | Error in message handler
# Traceback (most recent call last):
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 393, in dispatch_shell
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\jupyter_client\session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list

# %% [markdown]
# We can also filter all equations up to 2x the most accurate equation, then select the best score from that list:

# %%
best_idx = model.equations_.query(
    f"loss < {2 * model.equations_.loss.min()}"
).score.idxmax()
model.sympy(best_idx)
# Out:
# cos(x0*3.4933712)*5.0220137 - 1.2892635

# %% [markdown]
# We can also use `denoise=True`, which will run the input through a Gaussian process to denoise the dataset, before fitting on it.

# %% [markdown]
# Let's look at the fit:

# %%
plt.scatter(X[:, 0], y, alpha=0.1)
y_prediction = model.predict(X, index=best_idx)
plt.scatter(X[:, 0], y_prediction)

# %% [markdown]
# # Multiple outputs

# %% [markdown]
# For multiple outputs, multiple equations are returned:

# %%
X = 2 * np.random.randn(100, 5)
y = 1 / X[:, [0, 1, 2]]

# %%
model = PySRRegressor(
    binary_operators=["+", "*"],
    unary_operators=["inv(x) = 1/x"],
    extra_sympy_mappings={"inv": lambda x: 1 / x},
)
model.fit(X, y)
# Out:
# c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\pysr\sr.py:2776: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# Expressions evaluated per second: 4.020e+05
# Progress: 1933 / 9300 total iterations (20.785%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 1
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.969e+01  1.594e+01  y₀ = -1.3215
# 2           3.991e-14  1.594e+01  y₀ = inv(x₀)
# 4           3.988e-14  4.451e-04  y₀ = inv(x₀) + 3.7253e-09
# 6           2.438e-14  2.459e-01  y₀ = inv(x₀ * 0.80149) * 0.80149
# 11          2.340e-14  8.235e-03  y₀ = ((inv(x₀) * 0.077644) + (inv(x₀) * 0.92236)) + 9.442...
#                                        8e-09
# 12          2.290e-14  2.168e-02  y₀ = (((inv(x₃) + x₂) * 9.3118e-09) * inv(x₀)) + inv(x₀)
# 14          2.261e-14  6.441e-03  y₀ = ((inv(x₀) * 8.8432e-09) * (inv(x₃) + (x₂ + -0.73454)...
#                                        )) + inv(x₀)
# 15          2.048e-14  9.861e-02  y₀ = ((9.3118e-09 * inv(x₀)) * (inv(-1.0438) + (inv(x₃) +...
#                                         x₂))) + inv(x₀)
# 16          2.031e-14  8.272e-03  y₀ = inv(x₀) + ((-1.4102 + (inv(x₃) + x₂)) * ((inv(x₀) + ...
#                                        0.27762) * 9.3118e-09))
# 19          1.408e-14  1.223e-01  y₀ = inv(x₀) + ((((-0.11902 * inv(x₄)) + (inv(x₃) + x₂)) ...
#                                        * 9.3118e-09) * (inv(x₀) + -0.23259))
# 21          1.383e-14  8.912e-03  y₀ = inv(x₀) + (((((-0.11902 * inv(x₄ + -0.44672)) + inv(...
#                                        x₃)) + x₂) * 9.3118e-09) * (inv(x₀) + -0.23259))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 2
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.356e+02  1.594e+01  y₁ = -0.22252
# 2           2.336e-12  1.594e+01  y₁ = inv(x₁)
# 6           2.336e-12  1.878e-06  y₁ = inv(x₁) + (x₂ * -5.1757e-09)
# 7           1.361e-14  5.146e+00  y₁ = inv(x₁) + (inv(x₁) * -4.0911e-08)
# 9           7.609e-15  2.906e-01  y₁ = (inv(x₁ * x₁) * 2.5229e-10) + inv(x₁)
# 15          7.607e-15  4.863e-05  y₁ = inv(x₁) + ((inv(x₁ * (x₁ + x₁)) + (x₃ * x₁)) * 5.776...
#                                        e-10)
# 16          7.041e-15  7.735e-02  y₁ = inv(x₁) + ((inv(x₁ * (x₁ + x₁)) + (inv(x₂) * -0.3598...
#                                        5)) * 5.776e-10)
# 18          5.336e-15  1.387e-01  y₁ = inv(x₁) + ((inv((x₀ + -0.74319) * -1.0749) + inv(x₁ ...
#                                        * (x₁ + x₁))) * 5.776e-10)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.910e+04  1.594e+01  y₂ = 13.153
# 2           1.490e-10  1.594e+01  y₂ = inv(x₂)
# 4           6.788e-15  4.997e+00  y₂ = inv(x₂ + 3.483e-11)
# 11          5.178e-15  3.867e-02  y₂ = inv(x₂) + (inv(x₂) * ((x₄ + -4.053) * 6.0671e-09))
# 12          5.100e-15  1.512e-02  y₂ = inv(x₂) + ((inv(-0.19518) + x₄) * (inv(x₂) * 6.769e-...
#                                        09))
# 13          3.686e-15  3.248e-01  y₂ = ((((x₄ + -4.6488) * inv(x₂)) * 6.9912e-09) + -1.4211...
#                                        e-08) + inv(x₂)
# 14          2.951e-15  2.224e-01  y₂ = inv(x₂) + ((inv(x₂ + -0.27561) + x₄) * (inv(x₂) * 7....
#                                        1551e-09))
# 18          2.383e-15  5.349e-02  y₂ = inv(x₂) + ((inv(x₂) * ((x₄ + (x₂ * inv(x₂ + -0.18869...
#                                        ))) + -1.6467)) * 8.8056e-09)
# 22          2.380e-15  2.331e-04  y₂ = inv(x₂) + (inv(x₂) * ((x₄ + ((x₂ * (inv(x₂ + -0.1886...
#                                        9) + (-0.048187 * x₂))) + -1.6467)) * 8.8056e-09))
# 24          2.278e-15  2.193e-02  y₂ = inv(x₂) + (((x₄ + (((inv(x₂ + -0.18869) + (x₁ * (x₃ ...
#                                        * -0.31794))) * x₂) + -1.6467)) * 8.8056e-09) * inv(x₂))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.000e+05
# Progress: 3878 / 9300 total iterations (41.699%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 1
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.969e+01  1.594e+01  y₀ = -1.3215
# 2           3.991e-14  1.594e+01  y₀ = inv(x₀)
# 4           3.988e-14  4.451e-04  y₀ = inv(x₀) + 3.7253e-09
# 6           2.438e-14  2.459e-01  y₀ = inv(x₀ * 0.80149) * 0.80149
# 9           2.253e-14  2.643e-02  y₀ = (inv(x₀) * 0.96741) + (inv(x₀) * 0.03259)
# 11          2.229e-14  5.301e-03  y₀ = (inv(x₀) * 0.92236) + ((inv(x₀) * 0.077644) + 9.7921...
#                                        e-09)
# 14          1.403e-14  1.542e-01  y₀ = inv(x₀) + (((x₂ + inv(x₃)) + x₂) * (inv(x₀) * 1.0103...
#                                        e-08))
# 17          1.350e-14  1.285e-02  y₀ = inv(x₀) + (inv(x₀) * (((inv(x₄) * -0.2059) + (-1.215...
#                                        3 + inv(x₃))) * 7.5606e-09))
# 19          1.139e-14  8.513e-02  y₀ = inv(x₀) + ((((((-0.11902 * inv(x₄)) + inv(x₃)) + -1....
#                                        0037) + x₂) * 9.3118e-09) * inv(x₀))
# 21          1.120e-14  8.256e-03  y₀ = inv(x₀) + (inv(x₀) * (((((inv(x₄) * -0.2059) + -1.21...
#                                        53) + inv(x₃)) + (x₂ * 1.1823)) * 7.5606e-09))
# 30          1.108e-14  1.240e-03  y₀ = inv(x₀) + ((((((x₂ * inv(x₄)) + ((inv(x₃) + -1.0037)...
#                                         + (x₂ * 9.3118e-09))) * -0.11902) + (inv(x₃) + (x₂ + -1....
#                                        0037))) * 8.9571e-09) * inv(x₀))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 2
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.356e+02  1.594e+01  y₁ = -0.22252
# 2           2.336e-12  1.594e+01  y₁ = inv(x₁)
# 6           2.336e-12  1.878e-06  y₁ = inv(x₁) + (x₂ * -5.1757e-09)
# 7           1.344e-14  5.158e+00  y₁ = (inv(x₁) * -4.0134e-08) + inv(x₁)
# 9           7.609e-15  2.844e-01  y₁ = (inv(x₁ * x₁) * 2.5229e-10) + inv(x₁)
# 15          7.607e-15  4.863e-05  y₁ = inv(x₁) + ((inv(x₁ * (x₁ + x₁)) + (x₃ * x₁)) * 5.776...
#                                        e-10)
# 16          7.041e-15  7.735e-02  y₁ = inv(x₁) + ((inv(x₁ * (x₁ + x₁)) + (inv(x₂) * -0.3598...
#                                        5)) * 5.776e-10)
# 18          5.336e-15  1.387e-01  y₁ = inv(x₁) + ((inv((x₀ + -0.74319) * -1.0749) + inv(x₁ ...
#                                        * (x₁ + x₁))) * 5.776e-10)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.910e+04  1.594e+01  y₂ = 13.153
# 2           1.490e-10  1.594e+01  y₂ = inv(x₂)
# 4           6.788e-15  4.997e+00  y₂ = inv(x₂ + 3.483e-11)
# 9           6.575e-15  6.381e-03  y₂ = (inv(x₂) * 0.85036) + (inv(x₂) * 0.14964)
# 11          3.182e-15  3.629e-01  y₂ = inv(x₂) + (inv(x₂) * ((x₄ + -6.0778) * 5.6369e-09))
# 14          2.951e-15  2.511e-02  y₂ = inv(x₂) + ((inv(x₂ + -0.27561) + x₄) * (inv(x₂) * 7....
#                                        1551e-09))
# 18          2.383e-15  5.349e-02  y₂ = inv(x₂) + ((inv(x₂) * ((x₄ + (x₂ * inv(x₂ + -0.18869...
#                                        ))) + -1.6467)) * 8.8056e-09)
# 20          2.371e-15  2.335e-03  y₂ = inv(x₂) + ((inv(x₂) * (x₄ + (((inv(x₂ + -0.18869) + ...
#                                        -0.36196) * x₂) + -1.6467))) * 8.8056e-09)
# 22          2.276e-15  2.055e-02  y₂ = inv(x₂) + (((((x₂ * inv(x₂ + -0.18869)) + x₄) + -1.6...
#                                        467) + (x₃ * -0.43453)) * (inv(x₂) * 8.8056e-09))
# 24          1.874e-15  9.715e-02  y₂ = inv(x₂) + (((x₄ + ((inv((x₄ * -3.6311) + 0.71713) * ...
#                                        x₁) + ((x₃ * 0.33176) + -1.6467))) * inv(x₂)) * 8.8056e-0...
#                                        9)
# 26          1.577e-15  8.644e-02  y₂ = inv(x₂) + ((x₄ + ((inv((x₄ * -3.6311) + 0.71713) * x...
#                                        ₁) + ((x₁ * (x₃ * -0.31794)) + -1.6467))) * (inv(x₂) * 8....
#                                        8056e-09))
# 28          1.461e-15  3.803e-02  y₂ = ((((inv((x₄ * -3.6311) + 0.73699) * x₁) + x₄) + (((x...
#                                        ₁ * (x₂ + x₃)) * -0.31794) + -1.3667)) * (inv(x₂) * 8.805...
#                                        6e-09)) + inv(x₂)
# 30          1.459e-15  7.604e-04  y₂ = (((x₁ * inv((x₄ * -3.6311) + 0.73699)) + (x₄ + (((x₁...
#                                         * (x₂ + (x₃ * 1.3446))) * -0.31794) + -1.3667))) * (inv(...
#                                        x₂) * 8.8056e-09)) + inv(x₂)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.200e+05
# Progress: 6074 / 9300 total iterations (65.312%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 1
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.969e+01  1.594e+01  y₀ = -1.3215
# 2           3.991e-14  1.594e+01  y₀ = inv(x₀)
# 4           3.822e-14  2.172e-02  y₀ = inv(x₀) * 1
# 6           2.438e-14  2.247e-01  y₀ = inv(x₀ * 0.80149) * 0.80149
# 8           2.366e-14  1.507e-02  y₀ = inv(x₀ + ((x₀ * -2.7155e-08) * x₂))
# 9           2.153e-14  9.431e-02  y₀ = (inv(x₀) * 0.74194) + (inv(x₀) * 0.25806)
# 14          1.389e-14  8.766e-02  y₀ = inv(x₀) + ((((x₂ + x₂) + inv(x₃)) * inv(x₀)) * 9.941...
#                                        2e-09)
# 17          1.350e-14  9.457e-03  y₀ = inv(x₀) + (inv(x₀) * (((inv(x₄) * -0.2059) + (-1.215...
#                                        3 + inv(x₃))) * 7.5606e-09))
# 19          1.120e-14  9.339e-02  y₀ = inv(x₀) + (inv(x₀) * (((inv(x₄) * -0.19045) + (inv(x...
#                                        ₃) + (x₂ + -1.7256))) * 7.4301e-09))
# 21          1.107e-14  5.982e-03  y₀ = inv(x₀) + ((inv(x₀) * (inv(x₃) + ((x₂ + -1.7256) + (...
#                                        inv(x₄) * (x₂ * -0.12826))))) * 7.4301e-09)
# 22          1.048e-14  5.441e-02  y₀ = inv(x₀) + ((inv(((inv(x₄) + inv(x₃)) * 0.014167) + x...
#                                        ₃) + (x₂ + -1.2386)) * (inv(x₀) * 9.3118e-09))
# 26          1.033e-14  3.681e-03  y₀ = inv(x₀) + (((inv(((inv(x₄) + (x₁ * (inv(x₃) + 0.4461...
#                                        4))) * 0.014167) + x₃) + (x₂ + -1.0037)) * inv(x₀)) * 9.3...
#                                        118e-09)
# 28          1.031e-14  7.529e-04  y₀ = inv(x₀) + ((inv(x₀) * 9.3118e-09) * ((inv(((inv(x₄) ...
#                                        + ((inv(x₃) + 0.44614) * x₁)) * 0.014167) + x₃) + (x₀ + x...
#                                        ₂)) + -1.0037))
# 29          4.594e-15  8.087e-01  y₀ = inv(x₀) + (((inv(x₃) + (((inv((x₄ + (x₀ * x₀)) * ((x...
#                                        ₂ + -0.82845) * x₁)) * -0.14097) + x₂) + -1.3628)) * inv(...
#                                        x₀)) * 8.1086e-09)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 2
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.356e+02  1.594e+01  y₁ = -0.22252
# 2           2.336e-12  1.594e+01  y₁ = inv(x₁)
# 6           2.336e-12  1.878e-06  y₁ = inv(x₁) + (x₂ * -5.1757e-09)
# 7           1.344e-14  5.158e+00  y₁ = (inv(x₁) * -4.0134e-08) + inv(x₁)
# 9           7.609e-15  2.844e-01  y₁ = (inv(x₁ * x₁) * 2.5229e-10) + inv(x₁)
# 14          7.041e-15  1.553e-02  y₁ = (((inv(x₂) * x₀) + inv(x₁ * x₁)) * 2.1759e-10) + inv...
#                                        (x₁)
# 18          5.336e-15  6.933e-02  y₁ = inv(x₁) + ((inv((x₀ + -0.74319) * -1.0749) + inv(x₁ ...
#                                        * (x₁ + x₁))) * 5.776e-10)
# 20          4.767e-15  5.632e-02  y₁ = ((inv((x₀ + -0.74319) * (x₂ * 2.0159)) + inv(x₁ * (x...
#                                        ₁ + x₁))) * 5.776e-10) + inv(x₁)
# 30          4.758e-15  1.865e-04  y₁ = inv(x₁) + ((((x₀ * (((x₀ * 0.8507) + -1.8032) * -1.0...
#                                        749)) + inv((x₀ + -0.74319) * (1.8649 * x₂))) + inv(x₁ * ...
#                                        (x₁ + x₁))) * 5.776e-10)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.910e+04  1.594e+01  y₂ = 13.153
# 2           1.490e-10  1.594e+01  y₂ = inv(x₂)
# 4           6.788e-15  4.997e+00  y₂ = inv(x₂ + 3.483e-11)
# 9           6.575e-15  6.381e-03  y₂ = (inv(x₂) * 0.85036) + (inv(x₂) * 0.14964)
# 11          3.182e-15  3.629e-01  y₂ = inv(x₂) + (inv(x₂) * ((x₄ + -6.0778) * 5.6369e-09))
# 14          2.951e-15  2.511e-02  y₂ = inv(x₂) + ((inv(x₂ + -0.27561) + x₄) * (inv(x₂) * 7....
#                                        1551e-09))
# 16          2.656e-15  5.272e-02  y₂ = inv(x₂) + (((inv(x₂ + -0.27561) + x₄) * (inv(x₂) + x...
#                                        ₁)) * 7.1551e-09)
# 18          2.383e-15  5.426e-02  y₂ = inv(x₂) + ((inv(x₂) * ((x₄ + (x₂ * inv(x₂ + -0.18869...
#                                        ))) + -1.6467)) * 8.8056e-09)
# 20          1.910e-15  1.106e-01  y₂ = ((((inv((x₄ + -0.20853) * -3.6311) * x₁) + -1.7942) ...
#                                        + x₄) * (inv(x₂) * 8.8056e-09)) + inv(x₂)
# 24          1.865e-15  5.883e-03  y₂ = inv(x₂) + (((inv((x₄ * -3.6311) + 0.71713) * x₁) + (...
#                                        (x₃ * 0.23751) + (x₄ + -1.6467))) * (inv(x₂) * 8.8056e-09...
#                                        ))
# 26          1.521e-15  1.020e-01  y₂ = ((((((x₁ * x₃) * -0.4275) + -1.3667) + ((x₁ * inv((x...
#                                        ₄ * -3.6311) + 0.74751)) + x₄)) * inv(x₂)) * 8.8056e-09) ...
#                                        + inv(x₂)
# 28          1.461e-15  2.011e-02  y₂ = ((((inv((x₄ * -3.6311) + 0.73699) * x₁) + x₄) + (((x...
#                                        ₁ * (x₂ + x₃)) * -0.31794) + -1.3667)) * (inv(x₂) * 8.805...
#                                        6e-09)) + inv(x₂)
# 30          1.459e-15  7.604e-04  y₂ = (((x₁ * inv((x₄ * -3.6311) + 0.73699)) + (x₄ + (((x₁...
#                                         * (x₂ + (x₃ * 1.3446))) * -0.31794) + -1.3667))) * (inv(...
#                                        x₂) * 8.8056e-09)) + inv(x₂)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.280e+05
# Progress: 8233 / 9300 total iterations (88.527%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 1
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.969e+01  1.594e+01  y₀ = -1.3215
# 2           3.991e-14  1.594e+01  y₀ = inv(x₀)
# 4           3.822e-14  2.172e-02  y₀ = inv(x₀) * 1
# 6           2.438e-14  2.247e-01  y₀ = inv(x₀ * 0.80149) * 0.80149
# 8           2.366e-14  1.507e-02  y₀ = inv(x₀ + ((x₀ * -2.7155e-08) * x₂))
# 9           2.153e-14  9.431e-02  y₀ = (inv(x₀) * 0.74194) + (inv(x₀) * 0.25806)
# 14          1.389e-14  8.766e-02  y₀ = inv(x₀) + ((((x₂ + x₂) + inv(x₃)) * inv(x₀)) * 9.941...
#                                        2e-09)
# 17          1.336e-14  1.298e-02  y₀ = ((inv(x₀) * 6.034e-09) * ((inv(x₄) * -0.33525) + (in...
#                                        v(x₃) + -2.9099))) + inv(x₀)
# 19          1.120e-14  8.810e-02  y₀ = inv(x₀) + (inv(x₀) * (((inv(x₄) * -0.19045) + (inv(x...
#                                        ₃) + (x₂ + -1.7256))) * 7.4301e-09))
# 21          1.106e-14  6.383e-03  y₀ = inv(x₀) + (inv(x₀) * ((inv(x₃) + (x₂ + ((inv(x₄) * (...
#                                        x₂ * -0.13334)) + -2.7559))) * 6.1988e-09))
# 22          1.048e-14  5.361e-02  y₀ = inv(x₀) + ((inv(((inv(x₄) + inv(x₃)) * 0.014167) + x...
#                                        ₃) + (x₂ + -1.2386)) * (inv(x₀) * 9.3118e-09))
# 23          6.548e-15  4.706e-01  y₀ = ((((inv(x₃) + (inv(x₄ * (x₁ * (x₂ + -0.99067))) * -0...
#                                        .20037)) + -3.2857) * inv(x₀)) * 6.4152e-09) + inv(x₀)
# 24          4.843e-15  3.017e-01  y₀ = inv(x₀) + (((inv(x₃) + ((inv((x₂ + -0.93745) * x₄) *...
#                                         (inv(x₁) * -0.10546)) + x₁)) * inv(x₀)) * 6.6733e-09)
# 25          1.992e-15  8.885e-01  y₀ = ((inv(x₀) * 8.0218e-09) * (((inv(x₃) + (inv((x₄ * (x...
#                                        ₂ + -0.55714)) * x₁) * -0.14097)) + -1.3628) + x₂)) + inv...
#                                        (x₀)
# 29          1.956e-15  4.500e-03  y₀ = ((inv(x₀) * (inv(x₃) + ((inv((x₂ + -0.55714) * (x₄ *...
#                                         x₁)) * -0.14097) + (((x₃ * -0.40322) + -1.3628) + x₂))))...
#                                         * 8.0218e-09) + inv(x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 2
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.356e+02  1.594e+01  y₁ = -0.22252
# 2           2.336e-12  1.594e+01  y₁ = inv(x₁)
# 6           2.336e-12  2.101e-06  y₁ = inv(x₁) + (x₂ * -4.9382e-09)
# 7           1.344e-14  5.158e+00  y₁ = (inv(x₁) * -4.0134e-08) + inv(x₁)
# 9           7.609e-15  2.844e-01  y₁ = (inv(x₁ * x₁) * 2.5229e-10) + inv(x₁)
# 14          7.041e-15  1.553e-02  y₁ = (((inv(x₂) * x₀) + inv(x₁ * x₁)) * 2.1759e-10) + inv...
#                                        (x₁)
# 16          7.032e-15  6.310e-04  y₁ = (((inv(x₂) * (x₁ + -0.68558)) + inv(x₁ * x₁)) * 2.17...
#                                        59e-10) + inv(x₁)
# 18          5.336e-15  1.380e-01  y₁ = inv(x₁) + ((inv((x₀ + -0.74319) * -1.0749) + inv(x₁ ...
#                                        * (x₁ + x₁))) * 5.776e-10)
# 20          4.767e-15  5.632e-02  y₁ = ((inv((x₀ + -0.74319) * (x₂ * 2.0159)) + inv(x₁ * (x...
#                                        ₁ + x₁))) * 5.776e-10) + inv(x₁)
# 24          4.763e-15  2.329e-04  y₁ = inv(x₁) + (((inv((x₂ * (x₀ + -0.74319)) * 1.8649) + ...
#                                        (x₀ * 7.3325)) + inv(x₁ * (x₁ + x₁))) * 5.776e-10)
# 26          4.756e-15  6.997e-04  y₁ = inv(x₁) + (((((x₀ * x₀) * -1.9624) + inv((x₀ + -0.74...
#                                        319) * (x₂ * 1.8649))) + inv(x₁ * (x₁ + x₁))) * 5.776e-10...
#                                        )
# 27          4.599e-15  3.371e-02  y₁ = inv(x₁) + (((inv(x₃ * (x₀ + 0.57471)) + inv((x₀ + -0...
#                                        .74319) * (x₂ * 1.8649))) + inv((x₁ + x₁) * x₁)) * 5.776e...
#                                        -10)
# 29          4.199e-15  4.546e-02  y₁ = inv(x₁) + ((((inv(x₁ + 0.32194) * x₀) + -1.7769) + (...
#                                        inv((x₀ + -0.74319) * (x₂ * 1.8649)) + inv((x₁ + x₁) * x₁...
#                                        ))) * 5.776e-10)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Best equations for output 3
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.910e+04  1.594e+01  y₂ = 13.153
# 2           1.490e-10  1.594e+01  y₂ = inv(x₂)
# 4           6.788e-15  4.997e+00  y₂ = inv(x₂ + 3.483e-11)
# 9           6.575e-15  6.381e-03  y₂ = (inv(x₂) * 0.85036) + (inv(x₂) * 0.14964)
# 11          3.129e-15  3.713e-01  y₂ = inv(x₂) + (((-7.2783 + x₄) * inv(x₂)) * 4.6709e-09)
# 13          2.864e-15  4.412e-02  y₂ = inv(x₂) + ((x₂ + ((x₄ + -7.2783) * inv(x₂))) * 4.670...
#                                        9e-09)
# 16          2.391e-15  6.015e-02  y₂ = ((x₄ + inv(x₂ + -0.26287)) * ((inv(x₂) + -0.52696) *...
#                                         6.3356e-09)) + inv(x₂)
# 18          2.383e-15  1.860e-03  y₂ = inv(x₂) + ((inv(x₂) * ((x₄ + (x₂ * inv(x₂ + -0.18869...
#                                        ))) + -1.6467)) * 8.8056e-09)
# 20          1.910e-15  1.106e-01  y₂ = ((((inv((x₄ + -0.20853) * -3.6311) * x₁) + -1.7942) ...
#                                        + x₄) * (inv(x₂) * 8.8056e-09)) + inv(x₂)
# 24          1.779e-15  1.777e-02  y₂ = (((x₁ * 0.1762) + ((x₁ * inv((x₄ * -3.6311) + 0.7475...
#                                        1)) + (x₄ + -1.3667))) * (inv(x₂) * 8.8056e-09)) + inv(x₂...
#                                        )
# 26          1.521e-15  7.822e-02  y₂ = ((((((x₁ * x₃) * -0.4275) + -1.3667) + ((x₁ * inv((x...
#                                        ₄ * -3.6311) + 0.74751)) + x₄)) * inv(x₂)) * 8.8056e-09) ...
#                                        + inv(x₂)
# 28          1.461e-15  2.011e-02  y₂ = ((((inv((x₄ * -3.6311) + 0.73699) * x₁) + x₄) + (((x...
#                                        ₁ * (x₂ + x₃)) * -0.31794) + -1.3667)) * (inv(x₂) * 8.805...
#                                        6e-09)) + inv(x₂)
# 30          1.459e-15  7.604e-04  y₂ = (((x₁ * inv((x₄ * -3.6311) + 0.73699)) + (x₄ + (((x₁...
#                                         * (x₂ + (x₃ * 1.3446))) * -0.31794) + -1.3667))) * (inv(...
#                                        x₂) * 8.8056e-09)) + inv(x₂)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.969e+01  1.594e+01  y₀ = -1.3215
# 2           3.991e-14  1.594e+01  y₀ = inv(x₀)
# 4           3.822e-14  2.172e-02  y₀ = inv(x₀) * 1
# 6           2.438e-14  2.247e-01  y₀ = inv(x₀ * 0.80149) * 0.80149
# 8           2.366e-14  1.507e-02  y₀ = inv(x₀ + ((x₀ * -2.7155e-08) * x₂))
# 9           2.153e-14  9.431e-02  y₀ = (inv(x₀) * 0.74194) + (inv(x₀) * 0.25806)
# 14          1.389e-14  8.766e-02  y₀ = inv(x₀) + ((((x₂ + x₂) + inv(x₃)) * inv(x₀)) * 9.941...
#                                        2e-09)
# 17          1.320e-14  1.700e-02  y₀ = inv(x₀) + (inv((((inv(x₄) + inv(x₃)) * 0.014167) + x...
#                                        ₃) * x₀) * 1.3096e-08)
# 19          1.109e-14  8.726e-02  y₀ = inv(x₀) + (inv(x₀) * ((((inv(x₄) * -0.34407) + (inv(...
#                                        x₃) + x₂)) + -3.3347) * 5.754e-09))
# 21          1.106e-14  1.203e-03  y₀ = inv(x₀) + (inv(x₀) * ((inv(x₃) + (x₂ + ((inv(x₄) * (...
#                                        x₂ * -0.13334)) + -2.7559))) * 6.1988e-09))
# 22          1.048e-14  5.361e-02  y₀ = inv(x₀) + ((inv(((inv(x₄) + inv(x₃)) * 0.014167) + x...
#                                        ₃) + (x₂ + -1.2386)) * (inv(x₀) * 9.3118e-09))
# 23          5.962e-15  5.643e-01  y₀ = (inv(x₀) * (5.9094e-09 * (inv(x₃) + ((inv((x₄ * x₁) ...
#                                        * (x₂ + -0.79311)) * -0.20037) + -3.2857)))) + inv(x₀)
# 24          4.843e-15  2.079e-01  y₀ = inv(x₀) + (((inv(x₃) + ((inv((x₂ + -0.93745) * x₄) *...
#                                         (inv(x₁) * -0.10546)) + x₁)) * inv(x₀)) * 6.6733e-09)
# 25          1.992e-15  8.885e-01  y₀ = ((inv(x₀) * 8.0218e-09) * (((inv(x₃) + (inv((x₄ * (x...
#                                        ₂ + -0.55714)) * x₁) * -0.14097)) + -1.3628) + x₂)) + inv...
#                                        (x₀)
# 29          1.956e-15  4.500e-03  y₀ = ((inv(x₀) * (inv(x₃) + ((inv((x₂ + -0.55714) * (x₄ *...
#                                         x₁)) * -0.14097) + (((x₃ * -0.40322) + -1.3628) + x₂))))...
#                                         * 8.0218e-09) + inv(x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           6.356e+02  1.594e+01  y₁ = -0.22252
# 2           2.336e-12  1.594e+01  y₁ = inv(x₁)
# 6           2.336e-12  2.101e-06  y₁ = inv(x₁) + (x₂ * -4.9382e-09)
# 7           1.344e-14  5.158e+00  y₁ = (inv(x₁) * -4.0134e-08) + inv(x₁)
# 9           7.609e-15  2.844e-01  y₁ = (inv(x₁ * x₁) * 2.5229e-10) + inv(x₁)
# 13          7.607e-15  7.295e-05  y₁ = (((x₂ * -8.7174) + inv(x₁ * x₁)) * 2.1759e-10) + inv...
#                                        (x₁)
# 14          7.041e-15  7.735e-02  y₁ = (((inv(x₂) * x₀) + inv(x₁ * x₁)) * 2.1759e-10) + inv...
#                                        (x₁)
# 16          7.032e-15  6.310e-04  y₁ = (((inv(x₂) * (x₁ + -0.68558)) + inv(x₁ * x₁)) * 2.17...
#                                        59e-10) + inv(x₁)
# 18          5.336e-15  1.380e-01  y₁ = inv(x₁) + ((inv((x₀ + -0.74319) * -1.0749) + inv(x₁ ...
#                                        * (x₁ + x₁))) * 5.776e-10)
# 20          4.767e-15  5.632e-02  y₁ = ((inv((x₀ + -0.74319) * (x₂ * 2.0159)) + inv(x₁ * (x...
#                                        ₁ + x₁))) * 5.776e-10) + inv(x₁)
# 24          4.763e-15  2.329e-04  y₁ = inv(x₁) + (((inv((x₂ * (x₀ + -0.74319)) * 1.8649) + ...
#                                        (x₀ * 7.3325)) + inv(x₁ * (x₁ + x₁))) * 5.776e-10)
# 25          4.199e-15  1.260e-01  y₁ = ((inv((x₁ + x₁) * x₁) + (inv((1.8649 * (x₀ + -0.7431...
#                                        9)) * x₂) + inv(x₁ + -0.36183))) * 5.776e-10) + inv(x₁)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.910e+04  1.594e+01  y₂ = 13.153
# 2           1.490e-10  1.594e+01  y₂ = inv(x₂)
# 4           6.788e-15  4.997e+00  y₂ = inv(x₂ + 3.483e-11)
# 9           6.575e-15  6.381e-03  y₂ = (inv(x₂) * 0.85036) + (inv(x₂) * 0.14964)
# 11          3.129e-15  3.713e-01  y₂ = inv(x₂) + (((-7.2783 + x₄) * inv(x₂)) * 4.6709e-09)
# 13          2.864e-15  4.412e-02  y₂ = inv(x₂) + ((x₂ + ((x₄ + -7.2783) * inv(x₂))) * 4.670...
#                                        9e-09)
# 15          2.858e-15  1.164e-03  y₂ = inv(x₂) + (((-0.08553 + x₂) + (inv(x₂) * (x₄ + -7.27...
#                                        83))) * 4.6709e-09)
# 16          2.383e-15  1.819e-01  y₂ = ((x₄ + inv(x₂ + -0.263)) * ((inv(x₂) + -0.39879) * 5...
#                                        .9051e-09)) + inv(x₂)
# 18          2.198e-15  4.025e-02  y₂ = ((x₄ + inv(x₂ + -0.263)) * ((inv(x₂) + (x₁ * 0.60691...
#                                        )) * 5.9051e-09)) + inv(x₂)
# 20          1.910e-15  7.039e-02  y₂ = ((((inv((x₄ + -0.20853) * -3.6311) * x₁) + -1.7942) ...
#                                        + x₄) * (inv(x₂) * 8.8056e-09)) + inv(x₂)
# 24          1.779e-15  1.777e-02  y₂ = (((x₁ * 0.1762) + ((x₁ * inv((x₄ * -3.6311) + 0.7475...
#                                        1)) + (x₄ + -1.3667))) * (inv(x₂) * 8.8056e-09)) + inv(x₂...
#                                        )
# 26          1.521e-15  7.822e-02  y₂ = ((((((x₁ * x₃) * -0.4275) + -1.3667) + ((x₁ * inv((x...
#                                        ₄ * -3.6311) + 0.74751)) + x₄)) * inv(x₂)) * 8.8056e-09) ...
#                                        + inv(x₂)
# 28          1.461e-15  2.011e-02  y₂ = ((((inv((x₄ * -3.6311) + 0.73699) * x₁) + x₄) + (((x...
#                                        ₁ * (x₂ + x₃)) * -0.31794) + -1.3667)) * (inv(x₂) * 8.805...
#                                        6e-09)) + inv(x₂)
# 30          1.459e-15  7.604e-04  y₂ = (((x₁ * inv((x₄ * -3.6311) + 0.73699)) + (x₄ + (((x₁...
#                                         * (x₂ + (x₃ * 1.3446))) * -0.31794) + -1.3667))) * (inv(...
#                                        x₂) * 8.8056e-09)) + inv(x₂)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
#   - outputs\20250510_150029_X9fhD3\hall_of_fame_output1.csv
#   - outputs\20250510_150029_X9fhD3\hall_of_fame_output2.csv
# [ Info: Final populations:
# [ Info: Output 1:
# [ Info: Output 2:
# [ Info: Output 3:
# [ Info: Results saved to:
# PySRRegressor.equations_ = [
# [
# 	    pick      score                                           equation  \
# 	0          0.000000                                         -1.3215482
# 	1         34.757929                                            inv(x0)
# 	2          0.021715                                      inv(x0) * 1.0
# 	3          0.224675                  inv(x0 * 0.80149114) * 0.80149114
# 	4          0.015067              inv(x0 + ((x0 * -2.7155401e-8) * x2))
# 	5          0.094307     (inv(x0) * 0.74193627) + (inv(x0) * 0.2580637)
# 	6          0.087655  inv(x0) + ((((x2 + x2) + inv(x3)) * inv(x0)) *...
# 	7          0.016997  inv(x0) + (inv((((inv(x4) + inv(x3)) * 0.01416...
# 	8          0.087257  inv(x0) + (inv(x0) * ((((inv(x4) * -0.34406966...
# 	9          0.001203  inv(x0) + (inv(x0) * ((inv(x3) + (x2 + ((inv(x...
# 	10         0.053610  inv(x0) + ((inv(((inv(x4) + inv(x3)) * 0.01416...
# 	11         0.564340  (inv(x0) * (5.909412e-9 * (inv(x3) + ((inv((x4...
# 	12         0.207897  inv(x0) + (((inv(x3) + ((inv((x2 + -0.9374541)...
# 	13  >>>>   0.888483  ((inv(x0) * 8.021768e-9) * (((inv(x3) + (inv((...
# 	14         0.004500  ((inv(x0) * (inv(x3) + ((inv((x2 + -0.55713755...
#
# 	            loss  complexity
# 	0   4.969471e+01           1
# 	1   3.991474e-14           2
# 	2   3.821832e-14           4
# 	3   2.438494e-14           6
# 	4   2.366107e-14           8
# 	5   2.153167e-14           9
# 	6   1.389111e-14          14
# 	7   1.320055e-14          17
# 	8   1.108669e-14          19
# 	9   1.106004e-14          21
# 	10  1.048273e-14          22
# 	11  5.961898e-15          23
# 	12  4.842793e-15          24
# 	13  1.991740e-15          25
# 	14  1.956213e-15          29
# ], [
# 	    pick      score                                           equation  \
# 	0          0.000000                                         -0.2225182
# 	1         33.237197                                            inv(x1)
# 	2          0.000002                     inv(x1) + (x2 * -4.9382134e-9)
# 	3          5.158054                 (inv(x1) * -4.013379e-8) + inv(x1)
# 	4          0.284352           (inv(x1 * x1) * 2.5229227e-10) + inv(x1)
# 	5          0.000073  (((x2 * -8.717421) + inv(x1 * x1)) * 2.1758584...
# 	6          0.077346  (((inv(x2) * x0) + inv(x1 * x1)) * 2.1758584e-...
# 	7          0.000631  (((inv(x2) * (x1 + -0.68557864)) + inv(x1 * x1...
# 	8   >>>>   0.138033  inv(x1) + ((inv((x0 + -0.7431919) * -1.0748667...
# 	9          0.056323  ((inv((x0 + -0.7431919) * (x2 * 2.015929)) + i...
# 	10         0.000233  inv(x1) + (((inv((x2 * (x0 + -0.7431919)) * 1....
# 	11         0.126034  ((inv((x1 + x1) * x1) + (inv((1.8648957 * (x0 ...
#
# 	            loss  complexity
# 	0   6.356064e+02           1
# 	1   2.335916e-12           2
# 	2   2.335896e-12           6
# 	3   1.343814e-14           7
# 	4   7.609469e-15           9
# 	5   7.607248e-15          13
# 	6   7.041034e-15          14
# 	7   7.032153e-15          16
# 	8   5.335732e-15          18
# 	9   4.767297e-15          20
# 	10  4.762857e-15          24
# 	11  4.198863e-15          25
# ], [
# 	    pick      score                                           equation  \
# 	0          0.000000                                          13.153298
# 	1         32.484459                                            inv(x2)
# 	2          4.998341                            inv(x2 + 3.4830205e-11)
# 	3          0.006381      (inv(x2) * 0.850364) + (inv(x2) * 0.14963597)
# 	4          0.371323  inv(x2) + (((-7.278255 + x4) * inv(x2)) * 4.67...
# 	5          0.044119  inv(x2) + ((x2 + ((x4 + -7.278255) * inv(x2)))...
# 	6          0.001164  inv(x2) + (((-0.0855303 + x2) + (inv(x2) * (x4...
# 	7          0.181855  ((x4 + inv(x2 + -0.26300153)) * ((inv(x2) + -0...
# 	8          0.040254  ((x4 + inv(x2 + -0.26300153)) * ((inv(x2) + (x...
# 	9          0.070386  ((((inv((x4 + -0.2085332) * -3.6311212) * x1) ...
# 	10         0.017768  (((x1 * 0.1761982) + ((x1 * inv((x4 * -3.63112...
# 	11  >>>>   0.078221  ((((((x1 * x3) * -0.4275046) + -1.3667428) + (...
# 	12         0.020107  ((((inv((x4 * -3.6311212) + 0.7369929) * x1) +...
# 	13         0.000760  (((x1 * inv((x4 * -3.6311212) + 0.7369929)) + ...
#
# 	            loss  complexity
# 	0   1.910123e+04           1
# 	1   1.490184e-10           2
# 	2   6.787903e-15           4
# 	3   6.574741e-15           9
# 	4   3.128609e-15          11
# 	5   2.864375e-15          13
# 	6   2.857714e-15          15
# 	7   2.382539e-15          16
# 	8   2.198242e-15          18
# 	9   1.909584e-15          20
# 	10  1.778577e-15          24
# 	11  1.521006e-15          26
# 	12  1.461053e-15          28
# 	13  1.458833e-15          30
# ]]
#   - outputs\20250510_150029_X9fhD3\hall_of_fame_output3.csv

# %%
model
# Out:
# PySRRegressor.equations_ = [
# [
# 	    pick      score                                           equation  \
# 	0          0.000000                                         -1.3215482
# 	1         34.757929                                            inv(x0)
# 	2          0.021715                                      inv(x0) * 1.0
# 	3          0.224675                  inv(x0 * 0.80149114) * 0.80149114
# 	4          0.015067              inv(x0 + ((x0 * -2.7155401e-8) * x2))
# 	5          0.094307     (inv(x0) * 0.74193627) + (inv(x0) * 0.2580637)
# 	6          0.087655  inv(x0) + ((((x2 + x2) + inv(x3)) * inv(x0)) *...
# 	7          0.016997  inv(x0) + (inv((((inv(x4) + inv(x3)) * 0.01416...
# 	8          0.087257  inv(x0) + (inv(x0) * ((((inv(x4) * -0.34406966...
# 	9          0.001203  inv(x0) + (inv(x0) * ((inv(x3) + (x2 + ((inv(x...
# 	10         0.053610  inv(x0) + ((inv(((inv(x4) + inv(x3)) * 0.01416...
# 	11         0.564340  (inv(x0) * (5.909412e-9 * (inv(x3) + ((inv((x4...
# 	12         0.207897  inv(x0) + (((inv(x3) + ((inv((x2 + -0.9374541)...
# 	13  >>>>   0.888483  ((inv(x0) * 8.021768e-9) * (((inv(x3) + (inv((...
# 	14         0.004500  ((inv(x0) * (inv(x3) + ((inv((x2 + -0.55713755...
#
# 	            loss  complexity
# 	0   4.969471e+01           1
# 	1   3.991474e-14           2
# 	2   3.821832e-14           4
# 	3   2.438494e-14           6
# 	4   2.366107e-14           8
# 	5   2.153167e-14           9
# 	6   1.389111e-14          14
# 	7   1.320055e-14          17
# 	8   1.108669e-14          19
# 	9   1.106004e-14          21
# 	10  1.048273e-14          22
# 	11  5.961898e-15          23
# 	12  4.842793e-15          24
# 	13  1.991740e-15          25
# 	14  1.956213e-15          29
# ], [
# 	    pick      score                                           equation  \
# 	0          0.000000                                         -0.2225182
# 	1         33.237197                                            inv(x1)
# 	2          0.000002                     inv(x1) + (x2 * -4.9382134e-9)
# 	3          5.158054                 (inv(x1) * -4.013379e-8) + inv(x1)
# 	4          0.284352           (inv(x1 * x1) * 2.5229227e-10) + inv(x1)
# 	5          0.000073  (((x2 * -8.717421) + inv(x1 * x1)) * 2.1758584...
# 	6          0.077346  (((inv(x2) * x0) + inv(x1 * x1)) * 2.1758584e-...
# 	7          0.000631  (((inv(x2) * (x1 + -0.68557864)) + inv(x1 * x1...
# 	8   >>>>   0.138033  inv(x1) + ((inv((x0 + -0.7431919) * -1.0748667...
# 	9          0.056323  ((inv((x0 + -0.7431919) * (x2 * 2.015929)) + i...
# 	10         0.000233  inv(x1) + (((inv((x2 * (x0 + -0.7431919)) * 1....
# 	11         0.126034  ((inv((x1 + x1) * x1) + (inv((1.8648957 * (x0 ...
#
# 	            loss  complexity
# 	0   6.356064e+02           1
# 	1   2.335916e-12           2
# 	2   2.335896e-12           6
# 	3   1.343814e-14           7
# 	4   7.609469e-15           9
# 	5   7.607248e-15          13
# 	6   7.041034e-15          14
# 	7   7.032153e-15          16
# 	8   5.335732e-15          18
# 	9   4.767297e-15          20
# 	10  4.762857e-15          24
# 	11  4.198863e-15          25
# ], [
# 	    pick      score                                           equation  \
# 	0          0.000000                                          13.153298
# 	1         32.484459                                            inv(x2)
# 	2          4.998341                            inv(x2 + 3.4830205e-11)
# 	3          0.006381      (inv(x2) * 0.850364) + (inv(x2) * 0.14963597)
# 	4          0.371323  inv(x2) + (((-7.278255 + x4) * inv(x2)) * 4.67...
# 	5          0.044119  inv(x2) + ((x2 + ((x4 + -7.278255) * inv(x2)))...
# 	6          0.001164  inv(x2) + (((-0.0855303 + x2) + (inv(x2) * (x4...
# 	7          0.181855  ((x4 + inv(x2 + -0.26300153)) * ((inv(x2) + -0...
# 	8          0.040254  ((x4 + inv(x2 + -0.26300153)) * ((inv(x2) + (x...
# 	9          0.070386  ((((inv((x4 + -0.2085332) * -3.6311212) * x1) ...
# 	10         0.017768  (((x1 * 0.1761982) + ((x1 * inv((x4 * -3.63112...
# 	11  >>>>   0.078221  ((((((x1 * x3) * -0.4275046) + -1.3667428) + (...
# 	12         0.020107  ((((inv((x4 * -3.6311212) + 0.7369929) * x1) +...
# 	13         0.000760  (((x1 * inv((x4 * -3.6311212) + 0.7369929)) + ...
#
# 	            loss  complexity
# 	0   1.910123e+04           1
# 	1   1.490184e-10           2
# 	2   6.787903e-15           4
# 	3   6.574741e-15           9
# 	4   3.128609e-15          11
# 	5   2.864375e-15          13
# 	6   2.857714e-15          15
# 	7   2.382539e-15          16
# 	8   2.198242e-15          18
# 	9   1.909584e-15          20
# 	10  1.778577e-15          24
# 	11  1.521006e-15          26
# 	12  1.461053e-15          28
# 	13  1.458833e-15          30
# ]]
# [IPKernelApp] ERROR | Error in message handler
# Traceback (most recent call last):
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 393, in dispatch_shell
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\jupyter_client\session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# [IPKernelApp] ERROR | Error in message handler
# Traceback (most recent call last):
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 393, in dispatch_shell
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\jupyter_client\session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# [IPKernelApp] ERROR | Error in message handler
# Traceback (most recent call last):
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 393, in dispatch_shell
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\jupyter_client\session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# [IPKernelApp] ERROR | Error in message handler
# Traceback (most recent call last):
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 393, in dispatch_shell
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\jupyter_client\session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# [IPKernelApp] ERROR | Error in message handler
# Traceback (most recent call last):
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 393, in dispatch_shell
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\jupyter_client\session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list

# %% [markdown]
# # Julia packages and types

# %% [markdown]
# PySR uses [SymbolicRegression.jl](https://github.com/MilesCranmer/SymbolicRegression.jl)
# as its search backend. This is a pure Julia package, and so can interface easily with any other
# Julia package.
# For some tasks, it may be necessary to load such a package.
#
# For example, let's say we wish to discovery the following relationship:
#
# $$ y = p_{3x + 1} - 5, $$
#
# where $p_i$ is the $i$th prime number, and $x$ is the input feature.
#
# Let's see if we can discover this using
# the [Primes.jl](https://github.com/JuliaMath/Primes.jl) package.

# %% [markdown]
# `jl` stores the Julia runtime.
#
# Now, let's run some Julia code to add the Primes.jl
# package to the PySR environment:

# %%
from pysr import jl

jl.seval(
    """
import Pkg
Pkg.add("Primes")
"""
)
# Out:
#    Resolving package versions...
#   No Changes to `C:\Users\Adam\.julia\environments\pyjuliapkg\Project.toml`
#   No Changes to `C:\Users\Adam\.julia\environments\pyjuliapkg\Manifest.toml`

# %% [markdown]
# This imports the Julia package manager, and uses it to install
# `Primes.jl`. Now let's import `Primes.jl`:

# %%
jl.seval("using Primes: prime")
# Out:
# [IPKernelApp] ERROR | Error in message handler
# Traceback (most recent call last):
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 393, in dispatch_shell
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\jupyter_client\session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list

# %% [markdown]
# Note that PySR should automatically load the `juliacall.ipython` extension for you,
# which means that you can also execute Julia code in the notebook using the `%%julia` magic:

# %%
# %julia using Primes: prime

# %% [markdown]
# Now, we define a custom operator:

# %%
jl.seval(
    """
function p(i::T) where T
    if 0.5 < i < 1000
        return T(prime(round(Int, i)))
    else
        return T(NaN)
    end
end
"""
)
# Out:
# p (generic function with 1 method)

# %% [markdown]
# Or, equivalently:

# %%
# %%julia
# function p(i::T) where T
#     if 0.5 < i < 1000
#         return T(prime(round(Int, i)))
#     else
#         return T(NaN)
#     end
# end
# Out:
# p (generic function with 1 method)

# %% [markdown]
# We have created a function `p`, which takes a number `i` of type `T` (e.g., `T=Float64`).
# `p` first checks whether the input is between 0.5 and 1000.
# If out-of-bounds, it returns `NaN`.
# If in-bounds, it rounds it to the nearest integer, computes the corresponding prime number, and then
# converts it to the same type as input.
#
# The equivalent function in Python would be:
#
# ```python
# import sympy
#
# def p(i):
#     if 0.5 < i < 1000:
#         return float(sympy.prime(int(round(i))))
#     else:
#         return float("nan")
# ```
#
# (However, note that this version assumes 64-bit float input, rather than any input type `T`)
#
# Next, let's generate a list of primes for our test dataset.
# Since we are using juliacall, we can just call `p` directly to do this:

# %%
primes = {i: jl.p(i * 1.0) for i in range(1, 999)}

# %% [markdown]
# Next, let's use this list of primes to create a dataset of $x, y$ pairs:

# %%
import numpy as np

X = np.random.randint(0, 100, 100)[:, None]
y = [primes[3 * X[i, 0] + 1] - 5 + np.random.randn() * 0.001 for i in range(100)]

# %% [markdown]
# Note that we have also added a tiny bit of noise to the dataset.
#
# Finally, let's create a PySR model, and pass the custom operator. We also need to define the sympy equivalent, which we can leave as a placeholder for now:

# %%
from pysr import PySRRegressor
import sympy


class sympy_p(sympy.Function):
    pass


model = PySRRegressor(
    binary_operators=["+", "-", "*", "/"],
    unary_operators=["p"],
    niterations=20,
    extra_sympy_mappings={"p": sympy_p},
)

# %% [markdown]
# We are all set to go! Let's see if we can find the true relation:

# %%
model.fit(X, y)
# Out:
# c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\pysr\sr.py:2776: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# Expressions evaluated per second: 5.350e+04
# Progress: 294 / 620 total iterations (47.419%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.827e+05  1.594e+01  y = 890.47
# 3           3.145e+03  2.249e+00  y = x₀ * 18.387
# 5           7.682e+02  7.048e-01  y = (x₀ * 20.007) - 103.47
# 6           2.036e+01  3.631e+00  y = p((x₀ + 0.457) / 0.33486)
# 8           4.331e-02  3.076e+00  y = p((x₀ / 0.33418) + 1.4125) + -4.7919
# 10          1.104e-06  5.286e+00  y = p((x₀ + (x₀ + x₀)) + 0.87123) + -5
# 12          1.087e-06  7.778e-03  y = (p(((x₀ + x₀) + x₀) + 1.1171) + -4.9997) * 1
# 16          1.087e-06  4.623e-05  y = ((p((x₀ - 0.14468) + ((x₀ + 1.3387) + x₀)) + -4.9061) ...
#                                       * 1) - 0.093687
# 22          1.085e-06  2.316e-04  y = (p((x₀ - -0.15769) + ((x₀ + -0.376) + ((x₀ + (x₀ - (x₀...
#                                        - 0.22946))) + 0.82142))) + -4.9998) * 1
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 4.870e+04
# Progress: 534 / 620 total iterations (86.129%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.827e+05  1.594e+01  y = 890.47
# 3           3.145e+03  2.249e+00  y = x₀ * 18.387
# 5           7.682e+02  7.048e-01  y = (x₀ * 20.007) - 103.47
# 6           2.036e+01  3.631e+00  y = p((x₀ + 0.457) / 0.33486)
# 8           4.331e-02  3.076e+00  y = p((x₀ / 0.33418) + 1.4125) + -4.7919
# 10          1.104e-06  5.286e+00  y = p((x₀ + (x₀ + x₀)) + 0.87123) + -5
# 12          1.085e-06  8.671e-03  y = (p(x₀ + ((x₀ + x₀) + 0.76709)) + -4.9998) * 1
# 14          1.084e-06  5.531e-04  y = ((p((x₀ - -0.99172) + (x₀ + x₀)) - 0.046037) + -4.9538...
#                                       ) * 1
# 26          1.083e-06  7.278e-05  y = (x₀ + ((x₀ + (((p(((x₀ + x₀) + (x₀ - 0.27657)) + 1.532...
#                                       2) - x₀) + (-1.0155 - x₀)) + -1.3708)) + -2.8641)) - -0.25...
#                                       04
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           2.827e+05  1.594e+01  y = 890.47
# 3           3.145e+03  2.249e+00  y = x₀ * 18.387
# 5           7.682e+02  7.048e-01  y = (x₀ * 20.007) - 103.47
# 6           2.036e+01  3.631e+00  y = p((x₀ + 0.457) / 0.33486)
# 8           4.331e-02  3.076e+00  y = p((x₀ / 0.33418) + 1.4125) + -4.7919
# 10          1.104e-06  5.286e+00  y = p((x₀ + (x₀ + x₀)) + 0.87123) + -5
# 12          1.085e-06  8.671e-03  y = (p(x₀ + ((x₀ + x₀) + 0.76709)) + -4.9998) * 1
# 14          1.084e-06  5.531e-04  y = ((p((x₀ - -0.99172) + (x₀ + x₀)) - 0.046037) + -4.9538...
#                                       ) * 1
# 20          1.082e-06  3.167e-04  y = ((x₀ + ((p((x₀ + (x₀ - -0.85028)) + x₀) * 1) - 2.696))...
#                                        + -2.8266) - (x₀ - 0.52283)
# 22          1.081e-06  9.466e-05  y = x₀ + ((((p((x₀ + ((x₀ + 0.22597) - -0.85028)) + x₀) * ...
#                                       1) - 2.696) + -2.8266) - (x₀ - 0.52283))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
#   - outputs\20250510_150104_6UNJAU\hall_of_fame.csv
# [ Info: Final population:
# [ Info: Results saved to:
# PySRRegressor.equations_ = [
# 	   pick     score                                           equation  \
# 	0        0.000000                                           890.4681
# 	1        2.249288                                       x0 * 18.3867
# 	2        0.704811                         (x0 * 20.00683) - 103.4693
# 	3        3.630553                  p((x0 + 0.45699888) / 0.33485875)
# 	4        3.076449       p((x0 / 0.33417767) + 1.4124957) + -4.791876
# 	5  >>>>  5.288647       p((x0 + (x0 + x0)) + 0.8712333) + -4.9999614
# 	6        0.008671  (p(x0 + ((x0 + x0) + 0.7670946)) + -4.9997773)...
# 	7        0.000553  ((p((x0 - -0.9917248) + (x0 + x0)) - 0.0460369...
# 	8        0.000317  ((x0 + ((p((x0 + (x0 - -0.8502776)) + x0) * 0....
# 	9        0.000095  x0 + ((((p((x0 + ((x0 + 0.22597219) - -0.85027...
#
# 	            loss  complexity
# 	0  282735.880000           1
# 	1    3145.389200           3
# 	2     768.216430           5
# 	3      20.358908           6
# 	4       0.043310           8
# 	5       0.000001          10
# 	6       0.000001          12
# 	7       0.000001          14
# 	8       0.000001          20
# 	9       0.000001          22
# ]

# %% [markdown]
# if all works out, you should be able to see the true relation (note that the constant offset might not be exactly 1, since it is allowed to round to the nearest integer).
#
# You can get the sympy version of the best equation with:

# %%
model.sympy()
# Out:
# sympy_p(x0 + x0 + x0 + 0.8712333) - 4.9999614
# [IPKernelApp] ERROR | Error in message handler
# Traceback (most recent call last):
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 393, in dispatch_shell
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\jupyter_client\session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# [IPKernelApp] ERROR | Error in message handler
# Traceback (most recent call last):
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 393, in dispatch_shell
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\jupyter_client\session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list
# [IPKernelApp] ERROR | Error in message handler
# Traceback (most recent call last):
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py", line 393, in dispatch_shell
#     idents, msg = self.session.feed_identities(msg, copy=False)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\jupyter_client\session.py", line 994, in feed_identities
#     raise ValueError(msg)
# ValueError: DELIM not in msg_list

# %% [markdown]
# # High-dimensional input: Neural Nets + Symbolic Regression

# %% [markdown]
# In this example, let's learn a high-dimensional problem. **This will use the method proposed in our NeurIPS paper: https://arxiv.org/abs/2006.11287.**
#
# Let's consider a time series problem:
#
# $$ z = y^2,\quad y = \frac{1}{10} \sum(y_i),\quad y_i = x_{i0}^2 + 6 \cos(2*x_{i2})$$
#
# Imagine our time series is 10 timesteps. That is very hard for symbolic regression, even if we impose the inductive bias of $$z=f(\sum g(x_i))$$ - it is the square of the number of possible equations!
#
# But, as in our paper, **we can break this problem down into parts with a neural network. Then approximate the neural network with the symbolic regression!**
#
# Then, instead of, say, $(10^9)^2=10^{18}$ equations, we only have to consider $2\times 10^9$ equations.

# %%
import numpy as np

rstate = np.random.RandomState(0)

N = 100000
Nt = 10
X = 6 * rstate.rand(N, Nt, 5) - 3
y_i = X[..., 0] ** 2 + 6 * np.cos(2 * X[..., 2])
y = np.sum(y_i, axis=1) / y_i.shape[1]
z = y**2
X.shape, y.shape
# Out:
# ((100000, 10, 5), (100000,))

# %% [markdown]
# ## Neural Network definition

# %% [markdown]
# So, as described above, let's first use a neural network with the sum inductive bias to solve this problem.
#
# Essentially, we will learn two neural networks:
# - `f`
# - `g`
#
# each defined as a multi-layer perceptron. We will sum over `g` the same way as in our equation, but we won't define the summed part beforehand.
#
# Then, we will fit `g` and `f` **separately** using symbolic regression.

# %% [markdown]
# > **Warning**
# >
# > We import torch *after* already starting PyJulia. This is required due to interference between their C bindings. If you use torch, and then run PyJulia, you will likely hit a segfault. So keep this in mind for mixed deep learning + PyJulia/PySR workflows.

# %%
# !pip install pytorch_lightning
# Out:
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pytorch_lightning in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (2.5.1.post0)
# Requirement already satisfied: torch>=2.1.0 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from pytorch_lightning) (2.7.0+cu118)
# Requirement already satisfied: tqdm>=4.57.0 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from pytorch_lightning) (4.66.4)
# Requirement already satisfied: PyYAML>=5.4 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from pytorch_lightning) (6.0.1)
# Requirement already satisfied: fsspec>=2022.5.0 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (2024.6.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from pytorch_lightning) (1.7.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from pytorch_lightning) (23.2)
# Requirement already satisfied: typing-extensions>=4.4.0 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from pytorch_lightning) (4.13.2)
# Requirement already satisfied: lightning-utilities>=0.10.0 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from pytorch_lightning) (0.14.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (3.11.18)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.20.0)
# Requirement already satisfied: idna>=2.0 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (3.6)
# Requirement already satisfied: setuptools in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from lightning-utilities>=0.10.0->pytorch_lightning) (69.0.3)
# Requirement already satisfied: filelock in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from torch>=2.1.0->pytorch_lightning) (3.18.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from torch>=2.1.0->pytorch_lightning) (1.14.0)
# Requirement already satisfied: networkx in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from torch>=2.1.0->pytorch_lightning) (3.3)
# Requirement already satisfied: jinja2 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from torch>=2.1.0->pytorch_lightning) (3.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from sympy>=1.13.3->torch>=2.1.0->pytorch_lightning) (1.3.0)
# Requirement already satisfied: numpy>1.20.0 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from torchmetrics>=0.7.0->pytorch_lightning) (1.26.4)
# Requirement already satisfied: colorama in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.57.0->pytorch_lightning) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\adam\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch>=2.1.0->pytorch_lightning) (2.1.5)

# %%
import torch
from torch import nn, optim
from torch.nn import functional as F
from torch.utils.data import DataLoader, TensorDataset
import pytorch_lightning as pl

hidden = 128
total_steps = 50_000


def mlp(size_in, size_out, act=nn.ReLU):
    return nn.Sequential(
        nn.Linear(size_in, hidden),
        act(),
        nn.Linear(hidden, hidden),
        act(),
        nn.Linear(hidden, hidden),
        act(),
        nn.Linear(hidden, size_out),
    )


class SumNet(pl.LightningModule):
    def __init__(self):
        super().__init__()

        ########################################################
        # The same inductive bias as above!
        self.g = mlp(5, 1)
        self.f = mlp(1, 1)

    def forward(self, x):
        y_i = self.g(x)[:, :, 0]
        y = torch.sum(y_i, dim=1, keepdim=True) / y_i.shape[1]
        z = self.f(y)
        return z[:, 0]

    ########################################################

    # PyTorch Lightning bookkeeping:
    def training_step(self, batch, batch_idx):
        x, z = batch
        predicted_z = self(x)
        loss = F.mse_loss(predicted_z, z)
        return loss

    def validation_step(self, batch, batch_idx):
        return self.training_step(batch, batch_idx)

    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.parameters(), lr=self.max_lr)
        scheduler = {
            "scheduler": torch.optim.lr_scheduler.OneCycleLR(
                optimizer,
                max_lr=self.max_lr,
                total_steps=self.trainer.estimated_stepping_batches,
                final_div_factor=1e4,
            ),
            "interval": "step",
        }
        return [optimizer], [scheduler]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 5
#       3 from torch.nn import functional as F
#       4 from torch.utils.data import DataLoader, TensorDataset
# ----> 5 import pytorch_lightning as pl
#       7 hidden = 128
#       8 total_steps = 50_000
#
# File c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\pytorch_lightning\__init__.py:25
#      22     _logger.addHandler(logging.StreamHandler())
#      23     _logger.propagate = False
# ---> 25 from lightning_fabric.utilities.seed import seed_everything  # noqa: E402
#      26 from lightning_fabric.utilities.warnings import disable_possible_user_warnings  # noqa: E402
#      27 from pytorch_lightning.callbacks import Callback  # noqa: E402
#
# File c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\lightning_fabric\__init__.py:35
#      31 if sys.platform == "win32":
#      32     os.environ["USE_LIBUV"] = "0"
# ---> 35 from lightning_fabric.fabric import Fabric  # noqa: E402
#      36 from lightning_fabric.utilities.seed import seed_everything  # noqa: E402
#      37 from lightning_fabric.utilities.warnings import disable_possible_user_warnings  # noqa: E402
#
# File c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\lightning_fabric\fabric.py:40
#      38 from lightning_fabric.accelerators.accelerator import Accelerator
#      39 from lightning_fabric.connector import _PLUGIN_INPUT, _PRECISION_INPUT, _Connector, _is_using_cli
# ---> 40 from lightning_fabric.loggers import Logger
#      41 from lightning_fabric.plugins import Precision  # avoid circular imports: # isort: split
#      42 from lightning_fabric.strategies import (
#      43     DataParallelStrategy,
#      44     DeepSpeedStrategy,
#    (...)
#      48     XLAStrategy,
#      49 )
#
# File c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\lightning_fabric\loggers\__init__.py:15
#      13 from lightning_fabric.loggers.csv_logs import CSVLogger  # noqa: F401
#      14 from lightning_fabric.loggers.logger import Logger  # noqa: F401
# ---> 15 from lightning_fabric.loggers.tensorboard import TensorBoardLogger  # noqa: F401
#
# File c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\lightning_fabric\loggers\tensorboard.py:31
#      29 from lightning_fabric.utilities.rank_zero import rank_zero_only, rank_zero_warn
#      30 from lightning_fabric.utilities.types import _PATH
# ---> 31 from lightning_fabric.wrappers import _unwrap_objects
#      33 _TENSORBOARD_AVAILABLE = RequirementCache("tensorboard")
#      34 _TENSORBOARDX_AVAILABLE = RequirementCache("tensorboardX")
#
# File c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\lightning_fabric\wrappers.py:33
#      31 from torch import Tensor
#      32 from torch import nn as nn
# ---> 33 from torch._dynamo import OptimizedModule
#      34 from torch.nn.modules.module import _IncompatibleKeys
#      35 from torch.optim import Optimizer
#
# File c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\_dynamo\__init__.py:53
#      49 from .utils import graph_break_reasons, guard_failures, orig_code_map, reset_frame_count
#      52 # Register polyfill functions
# ---> 53 from .polyfills import loader as _  # usort: skip # noqa: F401
#      56 __all__ = [
#      57     "allow_in_graph",
#      58     "assume_constant_result",
#    (...)
#      82     "config",
#      83 ]
#      85 # allowlist this for weights_only load of NJTs
#
# File c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\_dynamo\polyfills\loader.py:25
#      14 # See also the TYPE_CHECKING block in torch/_dynamo/polyfills/__init__.py
#      15 POLYFILLED_MODULE_NAMES: tuple[str, ...] = (
#      16     "builtins",
#      17     "functools",
#    (...)
#      23     "fx",
#      24 )
# ---> 25 POLYFILLED_MODULES: tuple["ModuleType", ...] = tuple(
#      26     importlib.import_module(f".{submodule}", package=polyfills.__name__)
#      27     for submodule in POLYFILLED_MODULE_NAMES
#      28 )
#      31 # Unregister the builtin functions from _builtin_function_ids to let them to be
#      32 # dispatched with the appropriate VariableTracker type. Otherwise, they will be
#      33 # dispatched with BuiltinVariable if present in _builtin_function_ids.
#      34 for polyfill_module in POLYFILLED_MODULES:
#
# File c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\_dynamo\polyfills\loader.py:26, in <genexpr>(.0)
#      14 # See also the TYPE_CHECKING block in torch/_dynamo/polyfills/__init__.py
#      15 POLYFILLED_MODULE_NAMES: tuple[str, ...] = (
#      16     "builtins",
#      17     "functools",
#    (...)
#      23     "fx",
#      24 )
#      25 POLYFILLED_MODULES: tuple["ModuleType", ...] = tuple(
# ---> 26     importlib.import_module(f".{submodule}", package=polyfills.__name__)
#      27     for submodule in POLYFILLED_MODULE_NAMES
#      28 )
#      31 # Unregister the builtin functions from _builtin_function_ids to let them to be
#      32 # dispatched with the appropriate VariableTracker type. Otherwise, they will be
#      33 # dispatched with BuiltinVariable if present in _builtin_function_ids.
#      34 for polyfill_module in POLYFILLED_MODULES:
#
# File c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\importlib\__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\_dynamo\polyfills\builtins.py:30
#      19 __all__ = [
#      20     "all",
#      21     "any",
#      22     "enumerate",
#      23     "sum",
#      24 ]
#      27 _T = TypeVar("_T")
# ---> 30 @substitute_in_graph(builtins.all, can_constant_fold_through=True)
#      31 def all(iterable: Iterable[object], /) -> bool:
#      32     for elem in iterable:
#      33         if not elem:
#
# File c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\_dynamo\decorators.py:427, in substitute_in_graph.<locals>.wrapper(traceable_fn)
#     424 if id(original_fn) in _polyfilled_function_ids:
#     425     raise ValueError(f"Duplicate polyfilled object {original_fn}")
# --> 427 rule_map: dict[Any, type[VariableTracker]] = get_torch_obj_rule_map()
#     428 if original_fn in rule_map:
#     429     raise ValueError(
#     430         f"Duplicate object {original_fn} with different rules: "
#     431         f"{PolyfilledFunctionVariable}, {rule_map[original_fn]}"
#     432     )
#
# File c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\_dynamo\trace_rules.py:2870, in get_torch_obj_rule_map()
#    2868 for k, v in m.items():  # type: ignore[attr-defined]
#    2869     if ".py#" not in k:
# -> 2870         obj = load_object(k)
#    2871     else:
#    2872         obj = _module_dir(torch) + k[len("torch/") :]
#
# File c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\_dynamo\trace_rules.py:2901, in load_object(name)
#    2899     else:
#    2900         assert len(x) == 1, f"Invalid obj name {name}"
# -> 2901         val = _load_obj_from_str(x[0])
#    2902     val = unwrap_if_wrapper(val)
#    2903 except (AttributeError, ImportError):
#
# File c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\_dynamo\trace_rules.py:2885, in _load_obj_from_str(fully_qualified_name)
#    2883 def _load_obj_from_str(fully_qualified_name):
#    2884     module, obj_name = fully_qualified_name.rsplit(".", maxsplit=1)
# -> 2885     return getattr(importlib.import_module(module), obj_name)
#
# File c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\importlib\__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\_higher_order_ops\map.py:6
#       4 from torch._C import DispatchKey
#       5 from torch._dispatch.python import suspend_functionalization
# ----> 6 from torch._functorch.aot_autograd import AOTConfig, create_joint
#       7 from torch._higher_order_ops.utils import (
#       8     _has_potential_branch_input_alias,
#       9     _has_potential_branch_input_mutation,
#    (...)
#      12     UnsupportedAliasMutationException,
#      13 )
#      14 from torch._ops import HigherOrderOperator
#
# File c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\_functorch\aot_autograd.py:135
#     112 from ._aot_autograd.traced_function_transforms import (  # noqa: F401
#     113     aot_dispatch_subclass,
#     114     create_functional_call,
#    (...)
#     119     fn_prepped_for_autograd,
#     120 )
#     121 from ._aot_autograd.utils import (  # noqa: F401
#     122     _get_autocast_states,
#     123     _get_symint_hints,
#    (...)
#     133     strict_zip,
#     134 )
# --> 135 from .partitioners import default_partition
#     138 zip = strict_zip
#     140 # This global counter increments every time we compile a graph with
#     141 # AOTAutograd.  You can use this to correlate runtime error messages
#     142 # with compile time (e.g., if you get an error at runtime saying
#    (...)
#     149 # one counter is allocated per entire compiled block (but this block
#     150 # may involve compiling multiple subgraphs; e.g., for forwards/backwards)
#
# File c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\_functorch\partitioners.py:86
#      82     def is_recomputable(self, node: fx.Node):
#      83         return get_aten_target(node) in self.recomputable_ops
# ---> 86 @dataclass
#      87 class NodeInfo:
#      88     # Be careful about iterating over these explicitly, as their order may not
#      89     # be deterministic
#      90     inputs: list[fx.Node]
#      91     _required_fw_nodes: OrderedSet[fx.Node]
#
# File c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\dataclasses.py:1275, in dataclass(cls, init, repr, eq, order, unsafe_hash, frozen, match_args, kw_only, slots, weakref_slot)
#    1272     return wrap
#    1274 # We're called as @dataclass without parens.
# -> 1275 return wrap(cls)
#
# File c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\dataclasses.py:1265, in dataclass.<locals>.wrap(cls)
#    1264 def wrap(cls):
# -> 1265     return _process_class(cls, init, repr, eq, order, unsafe_hash,
#    1266                           frozen, match_args, kw_only, slots,
#    1267                           weakref_slot)
#
# File c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\dataclasses.py:1063, in _process_class(cls, init, repr, eq, order, unsafe_hash, frozen, match_args, kw_only, slots, weakref_slot)
#    1058 if init:
#    1059     # Does this class have a post-init function?
#    1060     has_post_init = hasattr(cls, _POST_INIT_NAME)
#    1062     _set_new_attribute(cls, '__init__',
# -> 1063                        _init_fn(all_init_fields,
#    1064                                 std_init_fields,
#    1065                                 kw_only_init_fields,
#    1066                                 frozen,
#    1067                                 has_post_init,
#    1068                                 # The name to use for the "self"
#    1069                                 # param in __init__.  Use "self"
#    1070                                 # if possible.
#    1071                                 '__dataclass_self__' if 'self' in fields
#    1072                                         else 'self',
#    1073                                 globals,
#    1074                                 slots,
#    1075                       ))
#    1077 # Get the fields as a list, and include only real fields.  This is
#    1078 # used in all of the following methods.
#    1079 field_list = [f for f in fields.values() if f._field_type is _FIELD]
#
# File c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\dataclasses.py:619, in _init_fn(fields, std_fields, kw_only_fields, frozen, has_post_init, self_name, globals, slots)
#     617     _init_params += ['*']
#     618     _init_params += [_init_param(f) for f in kw_only_fields]
# --> 619 return _create_fn('__init__',
#     620                   [self_name] + _init_params,
#     621                   body_lines,
#     622                   locals=locals,
#     623                   globals=globals,
#     624                   return_type=None)
#
# File c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\dataclasses.py:473, in _create_fn(name, args, body, globals, locals, return_type)
#     471 txt = f"def __create_fn__({local_vars}):\n{txt}\n return {name}"
#     472 ns = {}
# --> 473 exec(txt, globals, ns)
#     474 return ns['__create_fn__'](**locals)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Data bookkeeping

# %% [markdown]
# Put everything into PyTorch and do a train/test split:

# %%
from multiprocessing import cpu_count

Xt = torch.tensor(X).float()
zt = torch.tensor(z).float()
X_train, X_test, z_train, z_test = train_test_split(Xt, zt, random_state=0)
train_set = TensorDataset(X_train, z_train)
train = DataLoader(
    train_set, batch_size=128, num_workers=cpu_count(), shuffle=True, pin_memory=True
)
test_set = TensorDataset(X_test, z_test)
test = DataLoader(test_set, batch_size=256, num_workers=cpu_count(), pin_memory=True)

# %% [markdown]
# ## Train the model with PyTorch Lightning on GPUs:

# %% [markdown]
# Start the model:

# %%
pl.seed_everything(0)
model = SumNet()
model.total_steps = total_steps
model.max_lr = 1e-2
# Out:
# Seed set to 0

# %% [markdown]
# PyTorch Lightning trainer object:

# %%
trainer = pl.Trainer(max_steps=total_steps, accelerator="gpu", devices=1)
# Out:
# Using default `ModelCheckpoint`. Consider installing `litmodels` package to enable `LitModelCheckpoint` for automatic upload to the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs

# %% [markdown]
# Here, we fit the neural network:

# %%
trainer.fit(model, train_dataloaders=train, val_dataloaders=test)
# Out:
# You are using a CUDA device ('NVIDIA GeForce RTX 3070 Laptop GPU') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name | Type       | Params | Mode
# --------------------------------------------
# 0 | g    | Sequential | 33.9 K | train
# 1 | f    | Sequential | 33.4 K | train
# --------------------------------------------
# 67.3 K    Trainable params
# 0         Non-trainable params
# 67.3 K    Total params
# 0.269     Total estimated model params size (MB)
# 16        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:420: Consider setting `persistent_workers=True` in 'val_dataloader' to speed up the dataloader worker initialization.
# c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:420: Consider setting `persistent_workers=True` in 'train_dataloader' to speed up the dataloader worker initialization.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_steps=50000` reached.
# 2025-05-10 10:01:14.929483: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-10 10:01:18.058278: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %% [markdown]
# ## Latent vectors of network
#
# Let's get the input and output of the learned `g` function from the network over some random data:

# %%
np.random.seed(0)
idx = np.random.randint(0, 10000, size=1000)

X_for_pysr = Xt[idx]
y_i_for_pysr = model.g(X_for_pysr)[:, :, 0]
y_for_pysr = torch.sum(y_i_for_pysr, dim=1) / y_i_for_pysr.shape[1]
z_for_pysr = zt[idx]  # Use true values.

X_for_pysr.shape, y_i_for_pysr.shape
# Out:
# (torch.Size([1000, 10, 5]), torch.Size([1000, 10]))

# %% [markdown]
# ## Learning over the network:
#
# Now, let's fit `g` using PySR.
#
# > **Warning**
# >
# > First, let's save the data, because sometimes PyTorch and juliacall's C bindings interfere and cause the colab kernel to crash. If we need to restart, we can just load the data without having to retrain the network:

# %%
nnet_recordings = {
    "g_input": X_for_pysr.detach().cpu().numpy().reshape(-1, 5),
    "g_output": y_i_for_pysr.detach().cpu().numpy().reshape(-1),
    "f_input": y_for_pysr.detach().cpu().numpy().reshape(-1, 1),
    "f_output": z_for_pysr.detach().cpu().numpy().reshape(-1),
}

# Save the data for later use:
import pickle as pkl

with open("nnet_recordings.pkl", "wb") as f:
    pkl.dump(nnet_recordings, f)

# %% [markdown]
# We can now load the data, including after a crash (be sure to re-run the import cells at the top of this notebook, including the one that starts juliacall).

# %%
import pickle as pkl

nnet_recordings = pkl.load(open("nnet_recordings.pkl", "rb"))
f_input = nnet_recordings["f_input"]
f_output = nnet_recordings["f_output"]
g_input = nnet_recordings["g_input"]
g_output = nnet_recordings["g_output"]

# %% [markdown]
# And now fit using a subsample of the data (symbolic regression only needs a small sample to find the best equation):

# %%
rstate = np.random.RandomState(0)
f_sample_idx = rstate.choice(f_input.shape[0], size=500, replace=False)

model = PySRRegressor(
    niterations=50,
    binary_operators=["+", "-", "*"],
    unary_operators=["cos", "square"],
)
model.fit(g_input[f_sample_idx], g_output[f_sample_idx])
# Out:
# c:\Users\Adam\AppData\Local\Programs\Python\Python312\Lib\site-packages\pysr\sr.py:2776: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# Expressions evaluated per second: 1.730e+05
# Progress: 896 / 1550 total iterations (57.806%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.895e+02  1.594e+01  y = -2.272
# 2           1.845e+02  2.667e-02  y = square(x₀)
# 4           1.406e+02  1.356e-01  y = cos(x₀) * -10.893
# 6           5.625e+01  4.582e-01  y = cos(x₂ * -1.9706) * 17.397
# 7           5.508e+01  2.101e-02  y = (square(cos(x₂)) * 34.161) + -18.349
# 8           5.506e+01  4.220e-04  y = (cos(x₂ * -1.9924) * 17.124) + -1.2011
# 9           5.485e+01  3.711e-03  y = (square(cos(x₂)) * (33.997 - x₀)) + -18.289
# 10          2.316e+01  8.623e-01  y = (square(cos(x₂) * -5.8437) + square(x₀)) + -21.269
# 12          8.914e-03  3.931e+00  y = 2.8439 * ((square(x₀) + square(cos(x₂) * -3.4645)) + -...
#                                       9.3742)
# 14          8.819e-03  5.379e-03  y = ((square((cos(x₂) * -3.4641) + 0.00073435) + square(x₀...
#                                       )) * 2.8445) - 26.66
# 16          8.818e-03  2.348e-05  y = (((square((cos(x₂) * -3.4642) + 0.0007396) + square(x₀...
#                                       )) * 2.7241) - 25.533) * 1.0442
# 17          8.811e-03  8.558e-04  y = ((square(cos(x₂) * -3.4638) + (square(x₀) + -9.0241)) ...
#                                       * 2.8445) - cos(x₂ * 0.084843)
# 19          8.793e-03  1.014e-03  y = ((square(cos(x₂) * -3.4638) + (square(x₀) + -9.0241)) ...
#                                       * 2.8445) - cos((x₂ - 0.32841) * 0.084843)
# 20          8.766e-03  3.062e-03  y = ((-9.3721 + (square(x₀) + square(-3.464 * cos(x₂)))) *...
#                                        2.8446) - (0.015161 * cos(cos(x₃) - x₂))
# 22          8.763e-03  1.422e-04  y = ((-9.3721 + (square(x₀) + square(-3.464 * cos(x₂)))) *...
#                                        2.8446) - (0.015161 * cos(cos(x₃ * 0.81208) - x₂))
# 23          8.706e-03  6.549e-03  y = (((square(cos(x₂) * -3.4643) + square(x₀)) + -9.3734) ...
#                                       * 2.844) - (cos(x₂ - (x₃ * (x₀ * x₃))) * 0.02032)
# 25          8.657e-03  2.846e-03  y = ((-9.3721 + (square(x₀) + square(-3.464 * cos(x₂)))) *...
#                                        2.8446) - (cos(x₂ - cos((-1.2583 * x₃) + square(x₄))) * 0...
#                                       .015161)
# 29          8.634e-03  6.670e-04  y = (-1.0094 - (cos((square(x₂) * 3.7565) + cos((x₂ + 2.75...
#                                       72) * x₄)) * 0.022926)) + ((square(cos(x₂) * -3.4648) + (s...
#                                       quare(x₀) + -9.0204)) * 2.8444)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.895e+02  1.594e+01  y = -2.272
# 2           1.845e+02  2.667e-02  y = square(x₀)
# 4           1.406e+02  1.356e-01  y = cos(x₀) * -10.893
# 6           5.625e+01  4.582e-01  y = cos(x₂ * 1.9705) * 17.396
# 7           5.508e+01  2.101e-02  y = square(cos(x₂) * 5.8445) + -18.346
# 8           5.506e+01  4.219e-04  y = (cos(x₂ * -1.9924) * 17.124) + -1.2011
# 9           3.747e+01  3.848e-01  y = square(x₀) + (cos(x₂ * -1.9254) * 18.1)
# 10          2.316e+01  4.811e-01  y = (square(x₀) + -21.27) + square(cos(x₂) * 5.8437)
# 11          2.315e+01  3.950e-04  y = square(x₀) + ((cos(x₂ * -1.9952) * 17.103) + -4.1528)
# 12          8.914e-03  7.862e+00  y = ((square(cos(x₂)) * 12.003) + (square(x₀) + -9.3744)) ...
#                                       * 2.8438
# 14          8.818e-03  5.432e-03  y = ((square(x₀) * 2.844) + -26.659) + square((cos(x₂) * -...
#                                       5.8424) - -0.0011571)
# 17          8.809e-03  3.275e-04  y = ((square(cos(x₂) * -3.464) + (square(x₀) + -9.3763)) *...
#                                        2.8442) + square(x₂ * -0.060725)
# 19          8.793e-03  9.177e-04  y = ((square(cos(x₂) * -3.4638) + (square(x₀) + -9.0241)) ...
#                                       * 2.8445) - cos((x₂ - 0.32841) * 0.084843)
# 20          8.733e-03  6.855e-03  y = (2.8441 * (square(cos(x₂) * -3.4642) + (square(x₀) + -...
#                                       9.3733))) - ((cos(x₁) + cos(x₂)) * 0.015889)
# 22          8.662e-03  4.075e-03  y = ((-9.3721 + (square(-3.464 * cos(x₂)) + square(x₀))) *...
#                                        2.8446) - (0.015161 * cos(x₂ - cos(x₄ - x₃)))
# 25          8.589e-03  2.814e-03  y = ((square(x₀) + (square(cos(x₂) * -3.4647) + -9.373)) *...
#                                        2.8444) - (cos((x₂ * x₀) - square(square(x₂) + -0.15546))...
#                                        * 0.027644)
# 27          8.582e-03  3.926e-04  y = ((square(x₀) + -9.3739) + (square(cos(x₂) * -3.465) - ...
#                                       (cos((square(square(x₂) + -0.1664) + -0.0056709) - (x₀ * x...
#                                       ₂)) * 0.0093472))) * 2.8441
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# [ Info: Final population:
# [ Info: Results saved to:
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                         -2.2720466
# 	1         0.026666                                         square(x0)
# 	2         0.135644                              cos(x0) * -10.8926525
# 	3         0.458220                    cos(x2 * 1.9705154) * 17.396214
# 	4         0.021014             square(cos(x2) * 5.844549) + -18.34629
# 	5         0.000422    (cos(x2 * -1.9923617) * 17.124237) + -1.2010617
# 	6         0.384824    square(x0) + (cos(x2 * -1.9253627) * 18.099682)
# 	7         0.481143  (square(x0) + -21.269688) + square(cos(x2) * 5...
# 	8         0.000395  square(x0) + ((cos(x2 * -1.9952052) * 17.10288...
# 	9   >>>>  7.862129  ((square(cos(x2)) * 12.003096) + (square(x0) +...
# 	10        0.005432  ((square(x0) * 2.8440022) + -26.658577) + squa...
# 	11        0.000327  ((square(cos(x2) * -3.4640055) + (square(x0) +...
# 	12        0.000918  ((square(cos(x2) * -3.463826) + (square(x0) + ...
# 	13        0.006855  (2.8440986 * (square(cos(x2) * -3.4642377) + (...
# 	14        0.004075  ((-9.372128 + (square(-3.4640048 * cos(x2)) + ...
# 	15        0.002814  ((square(x0) + (square(cos(x2) * -3.4647367) +...
# 	16        0.000393  ((square(x0) + -9.37392) + (square(cos(x2) * -...
#
# 	          loss  complexity
# 	0   189.460450           1
# 	1   184.475070           2
# 	2   140.643330           4
# 	3    56.248910           6
# 	4    55.079224           7
# 	5    55.055984           8
# 	6    37.469456           9
# 	7    23.158990          10
# 	8    23.149841          11
# 	9     0.008914          12
# 	10    0.008818          14
# 	11    0.008809          17
# 	12    0.008793          19
# 	13    0.008733          20
# 	14    0.008662          22
# 	15    0.008589          25
# 	16    0.008582          27
# ]
#   - outputs\20250510_101934_IJOM8V\hall_of_fame.csv

# %% [markdown]
# If this segfaults, restart the notebook, and run the initial imports and juliacall part, but skip the PyTorch training. This is because PyTorch's C binding tends to interefere with juliacall. You can then re-run the `pkl.load` cell to import the data.

# %% [markdown]
# ## Validation

# %% [markdown]
# Recall we are searching for $f$ and $g$ such that:
# $$z=f(\sum g(x_i))$$
# which approximates the true relation:
# $$ z = y^2,\quad y = \frac{1}{10} \sum(y_i),\quad y_i = x_{i0}^2 + 6 \cos(2 x_{i2})$$
#
# Let's see how well we did in recovering $g$:

# %%
model.equations_[["complexity", "loss", "equation"]]
# Out:
#     complexity        loss                                           equation
# 0            1  189.460450                                         -2.2720466
# 1            2  184.475070                                         square(x0)
# 2            4  140.643330                              cos(x0) * -10.8926525
# 3            6   56.248910                    cos(x2 * 1.9705154) * 17.396214
# 4            7   55.079224             square(cos(x2) * 5.844549) + -18.34629
# 5            8   55.055984    (cos(x2 * -1.9923617) * 17.124237) + -1.2010617
# 6            9   37.469456    square(x0) + (cos(x2 * -1.9253627) * 18.099682)
# 7           10   23.158990  (square(x0) + -21.269688) + square(cos(x2) * 5...
# 8           11   23.149841  square(x0) + ((cos(x2 * -1.9952052) * 17.10288...
# 9           12    0.008914  ((square(cos(x2)) * 12.003096) + (square(x0) +...
# 10          14    0.008818  ((square(x0) * 2.8440022) + -26.658577) + squa...
# 11          17    0.008809  ((square(cos(x2) * -3.4640055) + (square(x0) +...
# 12          19    0.008793  ((square(cos(x2) * -3.463826) + (square(x0) + ...
# 13          20    0.008733  (2.8440986 * (square(cos(x2) * -3.4642377) + (...
# 14          22    0.008662  ((-9.372128 + (square(-3.4640048 * cos(x2)) + ...
# 15          25    0.008589  ((square(x0) + (square(cos(x2) * -3.4647367) +...
# 16          27    0.008582  ((square(x0) + -9.37392) + (square(cos(x2) * -...

# %% [markdown]
# A neural network can easily undo a linear transform (which commutes with the summation), so any affine transform in $g$ is to be expected. The network for $f$ has learned to undo the linear transform.
#
# This likely won't find the exact result, but it should find something similar. You may wish to try again but with many more `total_steps` for the neural network (10,000 is quite small!).
#
# Then, we can learn another analytic equation for $f$.

# %% [markdown]
# **Now, we can compose these together to get the time series model!**
#
# Think about what we just did: we found an analytical equation for $z$ in terms of $500$ datapoints, under the assumption that $z$ is a function of a sum of another function over an axis:
#
# $$ z = f(\sum_i g(x_i)) $$
#
# And we pulled out analytical copies for $g$ using symbolic regression.

# %% [markdown]
# # Other PySR Options

# %% [markdown]
# The full list of PySR parameters can be found here: https://astroautomata.com/PySR/api
