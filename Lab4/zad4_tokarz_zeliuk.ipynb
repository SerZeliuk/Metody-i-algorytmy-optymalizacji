# %% [markdown]
# # Zadanie 4: obliczenia ewolucyjne
#
# Adam Tokarz, Serhii Zeliuk
#
# EAIIIB ISI Metody i algorytmy optymalizacji grupa laboratoryjna 2 poniedziałek 18:30
#
# Termin realizacji: 5 maja 2025
#
# Zadanie do oddania przez MS Teams. Do oddania: kod oraz krótkie sprawozdanie w PDF (można na przykład przy użyciu `quarto render notebook.ipynb --to pdf`).
#
# ## Na 3.0
#
# Do realizacji:
#
# 1. Zmodyfikuj przykład "iterative method" z notatnika `tsp_lazy_constraints.ipynb` z poprzednich zajęć tak, aby rozwiązywał [problem podróżującego konsumenta](https://en.wikipedia.org/wiki/Traveling_purchaser_problem). Przykładowe problemy generuje poniższa funkcja `generate_random_tpp`. Przyjmij, że wszystkie miasta muszą być odwiedzone niezależnie od tego czy dokonany tam będzie zakup czy też nie. W rozwiązaniu wypisz w którym mieście kupione będą poszczególne przedmioty oraz narysuj trasę.
# 2. Zmodyfikuj analogicznie kod z notatnika `tsp-genetic.ipynb` tak aby rozwiązywał ten sam problem. Porównaj wydajność (czas obliczeń i wartość funkcji kosztu) dla dziewięciu losowych problemów, po trzy dla rozmiarów (n=50, k=20), (n=50, k=50) oraz (n=100, k=100). Dobierz parametry algorytmu genetycznego tak, aby czas działania nie przekraczał w żadnym przypadku minuty.
#
# ## Na 4.0
#
# Do realizacji:
#
# 1. Punkty z zadania na 3.0.
# 2. Zaimplementuj dodatkowo [krzyżowanie PMX](https://en.wikipedia.org/wiki/Crossover_(genetic_algorithm)#Partially_mapped_crossover_(PMX)) i porównaj wydajność z tym opartym o inwersję permutacji.
#
# ## Na 5.0
#
# Do realizacji:
#
# 1. Punkty z zadania na 4.0.
# 2. Zmodyfikuj problem tak, aby konsument nie musiał odwiedzać miast w których niczego nie kupuje.
# 3. Dodaj dodatkowo do porównania zmodyfikowany dla problemu podróżującego konsumenta przykład "lazy constraints" z notatnika `tsp_lazy_constraints.ipynb`.

# %% [markdown]
# # 4.1 Genrating tpp problem

# %%
using JuMP
import GLPK
import Random
import Plots

function generate_random_tpp(n, k; random_seed = 42)
    rng = Random.MersenneTwister(random_seed)
    # distance matrix
    X = 100 * rand(rng, n)
    Y = 100 * rand(rng, n)
    d = [sqrt((X[i] - X[j])^2 + (Y[i] - Y[j])^2) for i in 1:n, j in 1:n]

    cost_item_city = 50 .+ 100 .* rand(rng, k, n) # cost_item_city[num_item, num_city]

    return X, Y, d, cost_item_city
end

n = 100
k = 100
X, Y, d, cost_item_city = generate_random_tpp(n, k)
cost_item_city
# Out:
# 100×100 Matrix{Float64}:
#  121.647    80.9225   82.5522   68.4219  …   72.1259   93.1908   65.1287
#  100.459   130.856   118.259    69.0424     104.262   133.856    51.3516
#   67.6461   82.0081   71.3969  114.516       57.5011   54.4084  117.115
#  103.59    129.142    95.4103   69.2455     100.413    92.0191  118.853
#  109.536    83.7371   54.2522   82.9051      82.8586   75.2734  137.721
#  145.869   130.531    75.198   111.473   …   71.9345   80.5765  142.79
#  131.837   112.687   144.765    98.8433      87.3917   96.5618   76.3704
#  124.573   106.05    141.785   138.105      120.424    79.8209  120.373
#   83.3025   55.1765  121.658    87.9177      69.4409   51.546   105.33
#  108.888    61.9168   90.1995   87.2152      65.592   107.413    92.4529
#    ⋮                                     ⋱
#  135.944   109.882   136.142   112.31        52.8428  139.026    56.2198
#   73.2606  103.596   107.762   114.033       53.0942   73.7629   88.5433
#   58.9109   82.205    71.1763   85.7843      66.1907   84.6365   68.5659
#   98.8248  101.63    120.864    73.8973      79.4603   93.5478   72.677
#  109.597    79.7437   68.631   108.545   …  145.171   110.866    81.2931
#   60.8505   54.5912   90.3504   80.6286     115.53    130.338    85.0561
#  141.097    79.2896   91.0746   92.7237      55.8009  118.135   113.066
#   56.5249   56.8972   95.1388  111.688       92.9075   98.9807   53.5725
#   92.0708  137.181    86.5886  139.441       52.8286   77.978    97.3918

# %% [markdown]
# # 4.2 Iterative method - tpp

# %%
function build_tpp_model(d, cost_item_city, n, k)
    model = Model(GLPK.Optimizer)
    @variable(model, x[1:n, 1:n], Bin, Symmetric)
    @variable(model, y[1:k, 1:n], Bin) # y[i, j] = 1 if item i is bought in city j else y[i, j] = 0
    @objective(model, Min, sum(d .* x) / 2 + sum(cost_item_city .* y))
    @constraint(model, [i in 1:n], sum(x[i, :]) == 2)
    @constraint(model, [i in 1:n], x[i, i] == 0)
    @constraint(model, [i in 1:k], sum(y[i, :]) == 1) # each item need to be bought once
    return model
end

function subtour(edges::Vector{Tuple{Int,Int}}, n)
    shortest_subtour, unvisited = collect(1:n), Set(collect(1:n))
    while !isempty(unvisited)
        this_cycle, neighbors = Int[], unvisited
        while !isempty(neighbors)
            current = pop!(neighbors)
            push!(this_cycle, current)
            if length(this_cycle) > 1
                pop!(unvisited, current)
            end
            neighbors =
                [j for (i, j) in edges if i == current && j in unvisited]
        end
        if length(this_cycle) < length(shortest_subtour)
            shortest_subtour = this_cycle
        end
    end
    return shortest_subtour
end

function selected_edges(x::Matrix{Float64}, n)
    return Tuple{Int,Int}[(i, j) for i in 1:n, j in 1:n if x[i, j] > 0.5]
end

function bought_items(y::Matrix{Float64}, n, k)
    return sort(Tuple{Int,Int}[(i, j) for i in 1:k, j in 1:n if y[i, j] > 0.5], by = first)
end

subtour(x::Matrix{Float64}) = subtour(selected_edges(x, size(x, 1)), size(x, 1))
subtour(x::AbstractMatrix{VariableRef}) = subtour(value.(x))

function solve_tpp(X, Y, d, cost_item_city, n, k)
    iterative_model = build_tpp_model(d, cost_item_city, n, k)
    optimize!(iterative_model)
    @assert is_solved_and_feasible(iterative_model)
    time_iterated = solve_time(iterative_model)
    cycle = subtour(iterative_model[:x])
    while 1 < length(cycle) < n
        # println("Found cycle of length $(length(cycle))")
        S = [(i, j) for (i, j) in Iterators.product(cycle, cycle) if i < j]
        @constraint(
            iterative_model,
            sum(iterative_model[:x][i, j] for (i, j) in S) <= length(cycle) - 1,
        )
        optimize!(iterative_model)
        @assert is_solved_and_feasible(iterative_model)
        time_iterated += solve_time(iterative_model)
        cycle = subtour(iterative_model[:x])
    end

    obj = objective_value(iterative_model)
    return iterative_model, obj, time_iterated, X, Y
end
# Out:
# solve_tpp (generic function with 1 method)

# %%
import JuMP: value

function plot_tour(X, Y, x)
    plot = Plots.plot()
    Plots.scatter!(X, Y)
    for (i, j) in selected_edges(x, size(x, 1))
        Plots.plot!([X[i], X[j]], [Y[i], Y[j]]; legend = false)
    end
    return plot
end

function items_info(y::Matrix{Float64}, n, k)
    for (i, j) in bought_items(y, n, k)
        println("Item $i is bought in city $j")
    end
end


X, Y, d, cost_item_city = generate_random_tpp(50, 20)
it_model, obj, time_iterated, X, Y = solve_tpp(X, Y, d, cost_item_city, 50, 20)
println(obj)
println(time_iterated)
items_info(JuMP.value.(it_model[:y]), 50, 20)
plot_tour(X, Y, JuMP.value.(it_model[:x]))
# Out:
# 1551.8368298368384
# 0.14300012588500977
# Item 1 is bought in city 28
# Item 2 is bought in city 49
# Item 3 is bought in city 19
# Item 4 is bought in city 18
# Item 5 is bought in city 11
# Item 6 is bought in city 2
# Item 7 is bought in city 37
# Item 8 is bought in city 13
# Item 9 is bought in city 44
# Item 10 is bought in city 22
# Item 11 is bought in city 38
# Item 12 is bought in city 31
# Item 13 is bought in city 45
# Item 14 is bought in city 44
# Item 15 is bought in city 44
# Item 16 is bought in city 29
# Item 17 is bought in city 47
# Item 18 is bought in city 40
# Item 19 is bought in city 5
# Item 20 is bought in city 6

# %%
using DataFrames

n1, k1 = 50, 20
n2, k2 = 50, 50
n3, k3 = 100, 100
results_50_20 = []
results_50_50 = []
results_100_100 = []

println("n = $n1, k = $k1")
X, Y, d, cost_item_city = generate_random_tpp(n1, k1, random_seed=1)
it_model, obj, time_iterated, X, Y = solve_tpp(X, Y, d, cost_item_city, n1, k1)
push!(results_50_20, (obj, time_iterated))
items_info(value.(it_model[:y]), 50, 20)
plot_tour(X, Y, value.(it_model[:x]))
# Out:
# n = 50, k = 20
# Item 1 is bought in city 46
# Item 2 is bought in city 33
# Item 3 is bought in city 41
# Item 4 is bought in city 25
# Item 5 is bought in city 13
# Item 6 is bought in city 16
# Item 7 is bought in city 16
# Item 8 is bought in city 16
# Item 9 is bought in city 6
# Item 10 is bought in city 19
# Item 11 is bought in city 2
# Item 12 is bought in city 4
# Item 13 is bought in city 4
# Item 14 is bought in city 40
# Item 15 is bought in city 25
# Item 16 is bought in city 13
# Item 17 is bought in city 22
# Item 18 is bought in city 7
# Item 19 is bought in city 14
# Item 20 is bought in city 6

# %%
println("n = $n1, k = $k1")
X, Y, d, cost_item_city = generate_random_tpp(n1, k1, random_seed=2)
it_model, obj, time_iterated, X, Y = solve_tpp(X, Y, d, cost_item_city, n1, k1)
push!(results_50_20, (obj, time_iterated))
items_info(value.(it_model[:y]), 50, 20)
plot_tour(X, Y, value.(it_model[:x]))
# Out:
# n = 50, k = 20
# Item 1 is bought in city 39
# Item 2 is bought in city 17
# Item 3 is bought in city 34
# Item 4 is bought in city 36
# Item 5 is bought in city 36
# Item 6 is bought in city 7
# Item 7 is bought in city 19
# Item 8 is bought in city 14
# Item 9 is bought in city 27
# Item 10 is bought in city 6
# Item 11 is bought in city 48
# Item 12 is bought in city 7
# Item 13 is bought in city 16
# Item 14 is bought in city 43
# Item 15 is bought in city 22
# Item 16 is bought in city 7
# Item 17 is bought in city 17
# Item 18 is bought in city 12
# Item 19 is bought in city 2
# Item 20 is bought in city 17

# %%
println("n = $n1, k = $k1")
X, Y, d, cost_item_city = generate_random_tpp(n1, k1, random_seed=3)
it_model, obj, time_iterated, X, Y = solve_tpp(X, Y, d, cost_item_city, n1, k1)
push!(results_50_20, (obj, time_iterated))
items_info(value.(it_model[:y]), 50, 20)
plot_tour(X, Y, value.(it_model[:x]))
# Out:
# n = 50, k = 20
# Item 1 is bought in city 17
# Item 2 is bought in city 8
# Item 3 is bought in city 35
# Item 4 is bought in city 4
# Item 5 is bought in city 30
# Item 6 is bought in city 20
# Item 7 is bought in city 36
# Item 8 is bought in city 9
# Item 9 is bought in city 3
# Item 10 is bought in city 27
# Item 11 is bought in city 30
# Item 12 is bought in city 33
# Item 13 is bought in city 30
# Item 14 is bought in city 45
# Item 15 is bought in city 26
# Item 16 is bought in city 10
# Item 17 is bought in city 37
# Item 18 is bought in city 1
# Item 19 is bought in city 13
# Item 20 is bought in city 48

# %%
println("n = $n2, k = $k2")
X, Y, d, cost_item_city = generate_random_tpp(n2, k2, random_seed=4)
it_model, obj, time_iterated, X, Y = solve_tpp(X, Y, d, cost_item_city, n2, k2)
push!(results_50_50, (obj, time_iterated))
items_info(value.(it_model[:y]), n2, k2)
plot_tour(X, Y, value.(it_model[:x]))
# Out:
# n = 50, k = 50
# Item 1 is bought in city 11
# Item 2 is bought in city 38
# Item 3 is bought in city 42
# Item 4 is bought in city 41
# Item 5 is bought in city 22
# Item 6 is bought in city 30
# Item 7 is bought in city 39
# Item 8 is bought in city 1
# Item 9 is bought in city 2
# Item 10 is bought in city 12
# Item 11 is bought in city 14
# Item 12 is bought in city 28
# Item 13 is bought in city 25
# Item 14 is bought in city 5
# Item 15 is bought in city 12
# Item 16 is bought in city 18
# Item 17 is bought in city 40
# Item 18 is bought in city 28
# Item 19 is bought in city 30
# Item 20 is bought in city 26
# Item 21 is bought in city 36
# Item 22 is bought in city 20
# Item 23 is bought in city 25
# Item 24 is bought in city 29
# Item 25 is bought in city 27
# Item 26 is bought in city 36
# Item 27 is bought in city 49
# Item 28 is bought in city 8
# Item 29 is bought in city 9
# Item 30 is bought in city 50
# Item 31 is bought in city 38
# Item 32 is bought in city 45
# Item 33 is bought in city 28
# Item 34 is bought in city 16
# Item 35 is bought in city 13
# Item 36 is bought in city 2
# Item 37 is bought in city 23
# Item 38 is bought in city 19
# Item 39 is bought in city 25
# Item 40 is bought in city 14
# Item 41 is bought in city 28
# Item 42 is bought in city 41
# Item 43 is bought in city 31
# Item 44 is bought in city 18
# Item 45 is bought in city 38
# Item 46 is bought in city 12
# Item 47 is bought in city 33
# Item 48 is bought in city 47
# Item 49 is bought in city 14
# Item 50 is bought in city 36

# %%
println("n = $n2, k = $k2")
X, Y, d, cost_item_city = generate_random_tpp(n2, k2, random_seed=5)
it_model, obj, time_iterated, X, Y = solve_tpp(X, Y, d, cost_item_city, n2, k2)
push!(results_50_50, (obj, time_iterated))
items_info(value.(it_model[:y]), n2, k2)
plot_tour(X, Y, value.(it_model[:x]))
# Out:
# n = 50, k = 50
# Item 1 is bought in city 4
# Item 2 is bought in city 18
# Item 3 is bought in city 16
# Item 4 is bought in city 27
# Item 5 is bought in city 47
# Item 6 is bought in city 4
# Item 7 is bought in city 22
# Item 8 is bought in city 22
# Item 9 is bought in city 3
# Item 10 is bought in city 29
# Item 11 is bought in city 19
# Item 12 is bought in city 31
# Item 13 is bought in city 42
# Item 14 is bought in city 46
# Item 15 is bought in city 23
# Item 16 is bought in city 42
# Item 17 is bought in city 3
# Item 18 is bought in city 12
# Item 19 is bought in city 50
# Item 20 is bought in city 46
# Item 21 is bought in city 42
# Item 22 is bought in city 12
# Item 23 is bought in city 15
# Item 24 is bought in city 38
# Item 25 is bought in city 26
# Item 26 is bought in city 35
# Item 27 is bought in city 20
# Item 28 is bought in city 17
# Item 29 is bought in city 15
# Item 30 is bought in city 26
# Item 31 is bought in city 33
# Item 32 is bought in city 14
# Item 33 is bought in city 5
# Item 34 is bought in city 34
# Item 35 is bought in city 33
# Item 36 is bought in city 6
# Item 37 is bought in city 27
# Item 38 is bought in city 42
# Item 39 is bought in city 32
# Item 40 is bought in city 16
# Item 41 is bought in city 4
# Item 42 is bought in city 44
# Item 43 is bought in city 40
# Item 44 is bought in city 32
# Item 45 is bought in city 29
# Item 46 is bought in city 8
# Item 47 is bought in city 45
# Item 48 is bought in city 17
# Item 49 is bought in city 13
# Item 50 is bought in city 32

# %%
println("n = $n2, k = $k2")
X, Y, d, cost_item_city = generate_random_tpp(n2, k2, random_seed=6)
it_model, obj, time_iterated, X, Y = solve_tpp(X, Y, d, cost_item_city, n2, k2)
push!(results_50_50, (obj, time_iterated))
items_info(value.(it_model[:y]), n2, k2)
plot_tour(X, Y, value.(it_model[:x]))
# Out:
# n = 50, k = 50
# Item 1 is bought in city 12
# Item 2 is bought in city 17
# Item 3 is bought in city 38
# Item 4 is bought in city 20
# Item 5 is bought in city 7
# Item 6 is bought in city 26
# Item 7 is bought in city 39
# Item 8 is bought in city 10
# Item 9 is bought in city 2
# Item 10 is bought in city 2
# Item 11 is bought in city 6
# Item 12 is bought in city 49
# Item 13 is bought in city 30
# Item 14 is bought in city 36
# Item 15 is bought in city 24
# Item 16 is bought in city 43
# Item 17 is bought in city 24
# Item 18 is bought in city 36
# Item 19 is bought in city 40
# Item 20 is bought in city 21
# Item 21 is bought in city 2
# Item 22 is bought in city 29
# Item 23 is bought in city 45
# Item 24 is bought in city 48
# Item 25 is bought in city 22
# Item 26 is bought in city 8
# Item 27 is bought in city 35
# Item 28 is bought in city 34
# Item 29 is bought in city 28
# Item 30 is bought in city 45
# Item 31 is bought in city 30
# Item 32 is bought in city 18
# Item 33 is bought in city 11
# Item 34 is bought in city 17
# Item 35 is bought in city 20
# Item 36 is bought in city 24
# Item 37 is bought in city 36
# Item 38 is bought in city 42
# Item 39 is bought in city 37
# Item 40 is bought in city 19
# Item 41 is bought in city 17
# Item 42 is bought in city 27
# Item 43 is bought in city 29
# Item 44 is bought in city 23
# Item 45 is bought in city 45
# Item 46 is bought in city 48
# Item 47 is bought in city 48
# Item 48 is bought in city 49
# Item 49 is bought in city 11
# Item 50 is bought in city 2

# %%
println("n = $n3, k = $k3")
X, Y, d, cost_item_city = generate_random_tpp(n3, k3, random_seed=7)
it_model, obj, time_iterated, X, Y = solve_tpp(X, Y, d, cost_item_city, n3, k3)
push!(results_100_100, (obj, time_iterated))
items_info(value.(it_model[:y]), n3, k3)
plot_tour(X, Y, value.(it_model[:x]))
# Out:
# n = 100, k = 100
# Item 1 is bought in city 59
# Item 2 is bought in city 72
# Item 3 is bought in city 33
# Item 4 is bought in city 30
# Item 5 is bought in city 68
# Item 6 is bought in city 65
# Item 7 is bought in city 81
# Item 8 is bought in city 54
# Item 9 is bought in city 53
# Item 10 is bought in city 73
# Item 11 is bought in city 52
# Item 12 is bought in city 68
# Item 13 is bought in city 59
# Item 14 is bought in city 84
# Item 15 is bought in city 80
# Item 16 is bought in city 9
# Item 17 is bought in city 84
# Item 18 is bought in city 61
# Item 19 is bought in city 33
# Item 20 is bought in city 50
# Item 21 is bought in city 6
# Item 22 is bought in city 30
# Item 23 is bought in city 59
# Item 24 is bought in city 9
# Item 25 is bought in city 95
# Item 26 is bought in city 15
# Item 27 is bought in city 20
# Item 28 is bought in city 79
# Item 29 is bought in city 86
# Item 30 is bought in city 83
# Item 31 is bought in city 89
# Item 32 is bought in city 65
# Item 33 is bought in city 6
# Item 34 is bought in city 2
# Item 35 is bought in city 13
# Item 36 is bought in city 95
# Item 37 is bought in city 28
# Item 38 is bought in city 72
# Item 39 is bought in city 44
# Item 40 is bought in city 39
# Item 41 is bought in city 78
# Item 42 is bought in city 67
# Item 43 is bought in city 80
# Item 44 is bought in city 55
# Item 45 is bought in city 35
# Item 46 is bought in city 70
# Item 47 is bought in city 35
# Item 48 is bought in city 72
# Item 49 is bought in city 44
# Item 50 is bought in city 15
# Item 51 is bought in city 85
# Item 52 is bought in city 33
# Item 53 is bought in city 40
# Item 54 is bought in city 39
# Item 55 is bought in city 33
# Item 56 is bought in city 36
# Item 57 is bought in city 15
# Item 58 is bought in city 42
# Item 59 is bought in city 20
# Item 60 is bought in city 75
# Item 61 is bought in city 74
# Item 62 is bought in city 34
# Item 63 is bought in city 72
# Item 64 is bought in city 66
# Item 65 is bought in city 93
# Item 66 is bought in city 74
# Item 67 is bought in city 30
# Item 68 is bought in city 26
# Item 69 is bought in city 22
# Item 70 is bought in city 45
# Item 71 is bought in city 66
# Item 72 is bought in city 40
# Item 73 is bought in city 68
# Item 74 is bought in city 97
# Item 75 is bought in city 61
# Item 76 is bought in city 36
# Item 77 is bought in city 25
# Item 78 is bought in city 74
# Item 79 is bought in city 41
# Item 80 is bought in city 23
# Item 81 is bought in city 2
# Item 82 is bought in city 15
# Item 83 is bought in city 4
# Item 84 is bought in city 39
# Item 85 is bought in city 27
# Item 86 is bought in city 86
# Item 87 is bought in city 93
# Item 88 is bought in city 57
# Item 89 is bought in city 94
# Item 90 is bought in city 72
# Item 91 is bought in city 74
# Item 92 is bought in city 78
# Item 93 is bought in city 71
# Item 94 is bought in city 3
# Item 95 is bought in city 87
# Item 96 is bought in city 4
# Item 97 is bought in city 20
# Item 98 is bought in city 74
# Item 99 is bought in city 85
# Item 100 is bought in city 13

# %%
println("n = $n3, k = $k3")
X, Y, d, cost_item_city = generate_random_tpp(n3, k3, random_seed=8)
it_model, obj, time_iterated, X, Y = solve_tpp(X, Y, d, cost_item_city, n3, k3)
push!(results_100_100, (obj, time_iterated))
items_info(value.(it_model[:y]), n3, k3)
plot_tour(X, Y, value.(it_model[:x]))
# Out:
# n = 100, k = 100
# Item 1 is bought in city 91
# Item 2 is bought in city 20
# Item 3 is bought in city 4
# Item 4 is bought in city 78
# Item 5 is bought in city 76
# Item 6 is bought in city 60
# Item 7 is bought in city 88
# Item 8 is bought in city 40
# Item 9 is bought in city 22
# Item 10 is bought in city 64
# Item 11 is bought in city 19
# Item 12 is bought in city 25
# Item 13 is bought in city 17
# Item 14 is bought in city 91
# Item 15 is bought in city 42
# Item 16 is bought in city 43
# Item 17 is bought in city 2
# Item 18 is bought in city 12
# Item 19 is bought in city 56
# Item 20 is bought in city 29
# Item 21 is bought in city 10
# Item 22 is bought in city 29
# Item 23 is bought in city 76
# Item 24 is bought in city 86
# Item 25 is bought in city 66
# Item 26 is bought in city 82
# Item 27 is bought in city 90
# Item 28 is bought in city 66
# Item 29 is bought in city 66
# Item 30 is bought in city 93
# Item 31 is bought in city 8
# Item 32 is bought in city 19
# Item 33 is bought in city 83
# Item 34 is bought in city 80
# Item 35 is bought in city 5
# Item 36 is bought in city 54
# Item 37 is bought in city 49
# Item 38 is bought in city 26
# Item 39 is bought in city 16
# Item 40 is bought in city 81
# Item 41 is bought in city 89
# Item 42 is bought in city 45
# Item 43 is bought in city 94
# Item 44 is bought in city 71
# Item 45 is bought in city 7
# Item 46 is bought in city 83
# Item 47 is bought in city 16
# Item 48 is bought in city 93
# Item 49 is bought in city 21
# Item 50 is bought in city 85
# Item 51 is bought in city 52
# Item 52 is bought in city 46
# Item 53 is bought in city 84
# Item 54 is bought in city 12
# Item 55 is bought in city 69
# Item 56 is bought in city 53
# Item 57 is bought in city 73
# Item 58 is bought in city 56
# Item 59 is bought in city 13
# Item 60 is bought in city 96
# Item 61 is bought in city 93
# Item 62 is bought in city 62
# Item 63 is bought in city 13
# Item 64 is bought in city 52
# Item 65 is bought in city 47
# Item 66 is bought in city 45
# Item 67 is bought in city 46
# Item 68 is bought in city 99
# Item 69 is bought in city 88
# Item 70 is bought in city 18
# Item 71 is bought in city 20
# Item 72 is bought in city 95
# Item 73 is bought in city 54
# Item 74 is bought in city 77
# Item 75 is bought in city 77
# Item 76 is bought in city 92
# Item 77 is bought in city 85
# Item 78 is bought in city 52
# Item 79 is bought in city 7
# Item 80 is bought in city 63
# Item 81 is bought in city 55
# Item 82 is bought in city 92
# Item 83 is bought in city 96
# Item 84 is bought in city 23
# Item 85 is bought in city 41
# Item 86 is bought in city 13
# Item 87 is bought in city 64
# Item 88 is bought in city 80
# Item 89 is bought in city 96
# Item 90 is bought in city 51
# Item 91 is bought in city 47
# Item 92 is bought in city 27
# Item 93 is bought in city 49
# Item 94 is bought in city 68
# Item 95 is bought in city 66
# Item 96 is bought in city 66
# Item 97 is bought in city 3
# Item 98 is bought in city 90
# Item 99 is bought in city 40
# Item 100 is bought in city 100

# %%
println("n = $n3, k = $k3")
X, Y, d, cost_item_city = generate_random_tpp(n3, k3, random_seed=9)
it_model, obj, time_iterated, X, Y = solve_tpp(X, Y, d, cost_item_city, n3, k3)
push!(results_100_100, (obj, time_iterated))
items_info(value.(it_model[:y]), n3, k3)
plot_tour(X, Y, value.(it_model[:x]))
# Out:
# n = 100, k = 100
# Item 1 is bought in city 24
# Item 2 is bought in city 63
# Item 3 is bought in city 76
# Item 4 is bought in city 90
# Item 5 is bought in city 30
# Item 6 is bought in city 69
# Item 7 is bought in city 26
# Item 8 is bought in city 77
# Item 9 is bought in city 61
# Item 10 is bought in city 98
# Item 11 is bought in city 54
# Item 12 is bought in city 1
# Item 13 is bought in city 40
# Item 14 is bought in city 74
# Item 15 is bought in city 72
# Item 16 is bought in city 30
# Item 17 is bought in city 87
# Item 18 is bought in city 36
# Item 19 is bought in city 34
# Item 20 is bought in city 60
# Item 21 is bought in city 20
# Item 22 is bought in city 86
# Item 23 is bought in city 64
# Item 24 is bought in city 69
# Item 25 is bought in city 53
# Item 26 is bought in city 40
# Item 27 is bought in city 49
# Item 28 is bought in city 65
# Item 29 is bought in city 67
# Item 30 is bought in city 50
# Item 31 is bought in city 42
# Item 32 is bought in city 55
# Item 33 is bought in city 98
# Item 34 is bought in city 17
# Item 35 is bought in city 58
# Item 36 is bought in city 79
# Item 37 is bought in city 1
# Item 38 is bought in city 54
# Item 39 is bought in city 26
# Item 40 is bought in city 23
# Item 41 is bought in city 3
# Item 42 is bought in city 85
# Item 43 is bought in city 92
# Item 44 is bought in city 27
# Item 45 is bought in city 50
# Item 46 is bought in city 16
# Item 47 is bought in city 47
# Item 48 is bought in city 87
# Item 49 is bought in city 43
# Item 50 is bought in city 88
# Item 51 is bought in city 100
# Item 52 is bought in city 49
# Item 53 is bought in city 52
# Item 54 is bought in city 78
# Item 55 is bought in city 24
# Item 56 is bought in city 23
# Item 57 is bought in city 87
# Item 58 is bought in city 28
# Item 59 is bought in city 51
# Item 60 is bought in city 58
# Item 61 is bought in city 68
# Item 62 is bought in city 100
# Item 63 is bought in city 74
# Item 64 is bought in city 43
# Item 65 is bought in city 9
# Item 66 is bought in city 2
# Item 67 is bought in city 55
# Item 68 is bought in city 44
# Item 69 is bought in city 19
# Item 70 is bought in city 77
# Item 71 is bought in city 36
# Item 72 is bought in city 34
# Item 73 is bought in city 88
# Item 74 is bought in city 56
# Item 75 is bought in city 94
# Item 76 is bought in city 41
# Item 77 is bought in city 27
# Item 78 is bought in city 66
# Item 79 is bought in city 14
# Item 80 is bought in city 18
# Item 81 is bought in city 31
# Item 82 is bought in city 76
# Item 83 is bought in city 64
# Item 84 is bought in city 52
# Item 85 is bought in city 26
# Item 86 is bought in city 13
# Item 87 is bought in city 58
# Item 88 is bought in city 45
# Item 89 is bought in city 61
# Item 90 is bought in city 74
# Item 91 is bought in city 76
# Item 92 is bought in city 95
# Item 93 is bought in city 69
# Item 94 is bought in city 19
# Item 95 is bought in city 97
# Item 96 is bought in city 73
# Item 97 is bought in city 83
# Item 98 is bought in city 92
# Item 99 is bought in city 34
# Item 100 is bought in city 97

# %% [markdown]
# # 4.3 Permutation inversion - tpp

# %%
using Evolutionary
using Random
using Plots

function generate_random_tpp(n, k; random_seed = 42)
    rng = Random.MersenneTwister(random_seed)
    # distance matrix
    X = 100 * rand(rng, n)
    Y = 100 * rand(rng, n)
    d = [sqrt((X[i] - X[j])^2 + (Y[i] - Y[j])^2) for i in 1:n, j in 1:n]

    cost_item_city = 50 .+ 100 .* rand(rng, k, n) # cost_item_city[num_item, num_city]

    return X, Y, d, cost_item_city
end

function perm_to_inv(perm::Vector)
    N = length(perm)
    inv = zeros(Int, N)
    for i in 1:N
        m = 1
        while perm[m] != i
            if perm[m] > i
                inv[i] += 1
            end
            m += 1
        end
    end
    return inv
end

function inv_to_perm(inv::Vector)
    N = length(inv)
    pos = zeros(Int, N)
    for i in N:-1:1
        for m in (i+1):N
            if pos[m] >= inv[i] + 1
                pos[m] += 1
            end
        end
        pos[i] = inv[i] + 1
    end
    perm = zeros(Int, N)
    for i in 1:N
        perm[pos[i]] = i
    end
    return perm
end

function has_subtour(perm::Vector, n)
    perm = perm[1:n]
    visited = falses(n)
    current = 1
    tour_length = 0

    while !visited[current] && tour_length < n
        visited[current] = true
        current = perm[current]
        tour_length += 1
    end

    # Check if we visited all cities and ended back at start
    return tour_length < n || current != 1
end

function mutate_swap(recombinant::AbstractVector, n::Int;
    rng::AbstractRNG=Random.default_rng())
    N = length(recombinant)
    a = true
    while a || has_subtour(recombinant, n)
        i = rand(rng, 1:N)
        j = rand(rng, 1:N)
        v = recombinant[i]
        recombinant[i] = recombinant[j]
        recombinant[j] = v
        a = false
    end
    return recombinant
end

function recombine_tpp(v1::T, v2::T; rng::AbstractRNG=Random.default_rng()) where {T <: AbstractVector}
    N = length(v1)
    i1 = perm_to_inv(v1)
    i2 = perm_to_inv(v2)
    crossover_point = rand(2:(N-1))
    i1c = vcat(i1[1:crossover_point], i2[(crossover_point+1):N])
    i2c = vcat(i2[1:crossover_point], i1[(crossover_point+1):N])
    return inv_to_perm(i1c), inv_to_perm(i2c)
end

function crossover_tpp(p1, p2; rng=Random.default_rng())
    n = length(unique(p1))  
    k = length(p1) - n     

    x1, y1 = decode_individual(p1, n, k)
    x2, y2 = decode_individual(p2, n, k)

    cx1, cx2 = recombine_tpp(x1, x2; rng=rng)
    cy = rand(rng, Bool) ? y1 : y2

    return encode_individual(cx1, cy), encode_individual(cx2, cy)
end

function mutate_tpp(z; rng=Random.default_rng())
    n = length(unique(z))   
    k = length(z) - n        

    x, y = decode_individual(copy(z), n, k)
    x_mut = mutate_swap(x, n; rng=rng)
    y[rand(1:k)] = rand(rng, 1:n)
    return encode_individual(x_mut, y)
end

# individual will be presented as one vector [cities, items]
function encode_individual(x::Vector{Int}, y::Vector{Int})
    return vcat(x, y)
end

function decode_individual(z::Vector{Int}, n::Int, k::Int)
    x = z[1:n]
    y = z[(n+1):(n+k)]
    return x, y
end

function cost(z::Vector{Int})
    n = size(d, 1)
    k = size(cost_item_city, 1)
    x, y = decode_individual(z, n, k)

    travel_cost = 0.0
    for i in 1:length(x)
        travel_cost += d[i, x[i]]
    end

    purchase_cost = 0.0
    for item in 1:k
        city = y[item]
        purchase_cost += cost_item_city[item, city]
    end

    if has_subtour(x, n)
        travel_cost += 5000
    end

    return travel_cost + purchase_cost
end

#generate individual 
function random_individual(n, k)
    x = shuffle(1:n)
    y = rand(1:n, k)
    return encode_individual(x, y)
end
# Out:
# random_individual (generic function with 1 method)

# %%
n1, k1 = 50, 20
n2, k2 = 50, 50
n3, k3 = 100, 100

sol_50_20 = []
sol_50_50 = []
sol_100_100 = []
# Out:
# Any[]

# %%
using Dates
X, Y, d, cost_item_city = generate_random_tpp(50, 20, random_seed=1)

# solution is vector of visited cities and cities where item was bought so length(z) = n + k
opt_time = @elapsed begin
z_sol = Evolutionary.optimize(
    cost,
    () -> random_individual(50, 20),
    GA(; populationSize=10000, crossover=crossover_tpp, mutation=mutate_tpp, epsilon=0.01, crossoverRate=0.9),
    Evolutionary.Options(; iterations=10000)
)
end

println(has_subtour(z_sol.minimizer, 50))
println(z_sol)
# Out:
# false
#
#  * Status: success
#
#  * Candidate solution
#     Minimizer:  [48, 31, 47,  ...]
#     Minimum:    3004.2070865445803
#     Iterations: 75
#
#  * Found with
#     Algorithm: GA[P=10000,x=0.9,μ=0.1,ɛ=0.01]
#
#  * Convergence measures
#     |f(x) - f(x')| = 0.0 ≤ 1.0e-12
#
#  * Work counters
#     Seconds run:   12.069 (vs limit Inf)
#     Iterations:    75
#     f(x) calls:    760000

# %%
println(z_sol.minimizer)
println(size(z_sol.minimizer, 1))

push!(sol_50_20, (z_sol.minimum, opt_time))


function plot_tour(X, Y, x)
    plot = Plots.plot()
    scatter!(X, Y)
    for i in 1:length(x)
        j = x[i]
        Plots.plot!(plot, [X[i], X[j]], [Y[i], Y[j]]; legend = false)
    end
    return plot
end

function info_items(y)
    for i in 1:length(y)
        city = y[i]
        println("Item $i is bought in city $city")
    end
end

info_items(z_sol.minimizer[51:70])
plot_tour(X, Y, z_sol.minimizer[1:50])
# Out:
# [48, 31, 47, 25, 14, 18, 50, 11, 34, 6, 3, 33, 32, 22, 12, 17, 29, 45, 26, 1, 39, 38, 44, 15, 16, 20, 42, 23, 43, 9, 35, 37, 21, 13, 30, 46, 19, 4, 28, 36, 10, 7, 27, 2, 40, 5, 41, 49, 8, 24, 12, 35, 41, 17, 23, 22, 29, 44, 10, 8, 38, 21, 37, 19, 2, 22, 17, 29, 39, 44]
# 70
# Item 1 is bought in city 12
# Item 2 is bought in city 35
# Item 3 is bought in city 41
# Item 4 is bought in city 17
# Item 5 is bought in city 23
# Item 6 is bought in city 22
# Item 7 is bought in city 29
# Item 8 is bought in city 44
# Item 9 is bought in city 10
# Item 10 is bought in city 8
# Item 11 is bought in city 38
# Item 12 is bought in city 21
# Item 13 is bought in city 37
# Item 14 is bought in city 19
# Item 15 is bought in city 2
# Item 16 is bought in city 22
# Item 17 is bought in city 17
# Item 18 is bought in city 29
# Item 19 is bought in city 39
# Item 20 is bought in city 44

# %%
X, Y, d, cost_item_city = generate_random_tpp(n1, k1, random_seed=2)

# solution is vector of visited cities and cities where item was bought so length(z) = n + k
opt_time = @elapsed begin
z_sol = Evolutionary.optimize(
    cost,
    () -> random_individual(n1, k1),
    GA(; populationSize=10000, crossover=crossover_tpp, mutation=mutate_tpp, epsilon=0.01, crossoverRate=0.9),
    Evolutionary.Options(; iterations=10000)
)
end

println(has_subtour(z_sol.minimizer, n1))
println(z_sol)
# Out:
# false
#
#  * Status: success
#
#  * Candidate solution
#     Minimizer:  [42, 26, 24,  ...]
#     Minimum:    2619.1286157699988
#     Iterations: 83
#
#  * Found with
#     Algorithm: GA[P=10000,x=0.9,μ=0.1,ɛ=0.01]
#
#  * Convergence measures
#     |f(x) - f(x')| = 0.0 ≤ 1.0e-12
#
#  * Work counters
#     Seconds run:   12.95 (vs limit Inf)
#     Iterations:    83
#     f(x) calls:    840000

# %%
push!(sol_50_20, (z_sol.minimum, opt_time))
info_items(z_sol.minimizer[n1 + 1:n1 + k1])
plot_tour(X, Y, z_sol.minimizer[1:n1])
# Out:
# Item 1 is bought in city 48
# Item 2 is bought in city 21
# Item 3 is bought in city 20
# Item 4 is bought in city 37
# Item 5 is bought in city 3
# Item 6 is bought in city 1
# Item 7 is bought in city 24
# Item 8 is bought in city 33
# Item 9 is bought in city 26
# Item 10 is bought in city 14
# Item 11 is bought in city 6
# Item 12 is bought in city 25
# Item 13 is bought in city 31
# Item 14 is bought in city 5
# Item 15 is bought in city 12
# Item 16 is bought in city 1
# Item 17 is bought in city 25
# Item 18 is bought in city 9
# Item 19 is bought in city 6
# Item 20 is bought in city 25

# %%
X, Y, d, cost_item_city = generate_random_tpp(n1, k1, random_seed=3)

# solution is vector of visited cities and cities where item was bought so length(z) = n + k
opt_time = @elapsed begin
z_sol = Evolutionary.optimize(
    cost,
    () -> random_individual(n1, k1),
    GA(; populationSize=10000, crossover=crossover_tpp, mutation=mutate_tpp, epsilon=0.01, crossoverRate=0.9),
    Evolutionary.Options(; iterations=10000)
)
end

println(has_subtour(z_sol.minimizer, n1))
println(z_sol)
# Out:
# false
#
#  * Status: success
#
#  * Candidate solution
#     Minimizer:  [3, 37, 10,  ...]
#     Minimum:    3198.237493178428
#     Iterations: 36
#
#  * Found with
#     Algorithm: GA[P=10000,x=0.9,μ=0.1,ɛ=0.01]
#
#  * Convergence measures
#     |f(x) - f(x')| = 0.0 ≤ 1.0e-12
#
#  * Work counters
#     Seconds run:   6.371 (vs limit Inf)
#     Iterations:    36
#     f(x) calls:    370000

# %%
push!(sol_50_20, (z_sol.minimum, opt_time))
info_items(z_sol.minimizer[n1 + 1:n1 + k1])
plot_tour(X, Y, z_sol.minimizer[1:n1])
# Out:
# Item 1 is bought in city 19
# Item 2 is bought in city 25
# Item 3 is bought in city 30
# Item 4 is bought in city 10
# Item 5 is bought in city 41
# Item 6 is bought in city 32
# Item 7 is bought in city 41
# Item 8 is bought in city 5
# Item 9 is bought in city 26
# Item 10 is bought in city 44
# Item 11 is bought in city 43
# Item 12 is bought in city 36
# Item 13 is bought in city 22
# Item 14 is bought in city 40
# Item 15 is bought in city 33
# Item 16 is bought in city 19
# Item 17 is bought in city 34
# Item 18 is bought in city 3
# Item 19 is bought in city 4
# Item 20 is bought in city 21

# %%
X, Y, d, cost_item_city = generate_random_tpp(n2, k2, random_seed=4)

# solution is vector of visited cities and cities where item was bought so length(z) = n + k
opt_time = @elapsed begin
z_sol = Evolutionary.optimize(
    cost,
    () -> random_individual(n2, k2),
    GA(; populationSize=10000, crossover=crossover_tpp, mutation=mutate_tpp, epsilon=0.01, crossoverRate=0.9),
    Evolutionary.Options(; iterations=10000)
)
end

println(has_subtour(z_sol.minimizer, n2))
println(z_sol)
# Out:
# false
#
#  * Status: success
#
#  * Candidate solution
#     Minimizer:  [38, 16, 39,  ...]
#     Minimum:    5986.286744174209
#     Iterations: 73
#
#  * Found with
#     Algorithm: GA[P=10000,x=0.9,μ=0.1,ɛ=0.01]
#
#  * Convergence measures
#     |f(x) - f(x')| = 0.0 ≤ 1.0e-12
#
#  * Work counters
#     Seconds run:   16.683 (vs limit Inf)
#     Iterations:    73
#     f(x) calls:    740000

# %%
push!(sol_50_50, (z_sol.minimum, opt_time))
info_items(z_sol.minimizer[n2 + 1:n2 + k2])
plot_tour(X, Y, z_sol.minimizer[1:n2])
# Out:
# Item 1 is bought in city 35
# Item 2 is bought in city 38
# Item 3 is bought in city 49
# Item 4 is bought in city 44
# Item 5 is bought in city 17
# Item 6 is bought in city 47
# Item 7 is bought in city 13
# Item 8 is bought in city 45
# Item 9 is bought in city 39
# Item 10 is bought in city 32
# Item 11 is bought in city 38
# Item 12 is bought in city 50
# Item 13 is bought in city 22
# Item 14 is bought in city 42
# Item 15 is bought in city 45
# Item 16 is bought in city 18
# Item 17 is bought in city 21
# Item 18 is bought in city 24
# Item 19 is bought in city 31
# Item 20 is bought in city 2
# Item 21 is bought in city 17
# Item 22 is bought in city 45
# Item 23 is bought in city 19
# Item 24 is bought in city 39
# Item 25 is bought in city 2
# Item 26 is bought in city 5
# Item 27 is bought in city 40
# Item 28 is bought in city 27
# Item 29 is bought in city 31
# Item 30 is bought in city 20
# Item 31 is bought in city 14
# Item 32 is bought in city 33
# Item 33 is bought in city 45
# Item 34 is bought in city 4
# Item 35 is bought in city 33
# Item 36 is bought in city 15
# Item 37 is bought in city 20
# Item 38 is bought in city 22
# Item 39 is bought in city 18
# Item 40 is bought in city 10
# Item 41 is bought in city 13
# Item 42 is bought in city 6
# Item 43 is bought in city 48
# Item 44 is bought in city 19
# Item 45 is bought in city 2
# Item 46 is bought in city 20
# Item 47 is bought in city 21
# Item 48 is bought in city 14
# Item 49 is bought in city 33
# Item 50 is bought in city 11

# %%
X, Y, d, cost_item_city = generate_random_tpp(n2, k2, random_seed=5)

# solution is vector of visited cities and cities where item was bought so length(z) = n + k
opt_time = @elapsed begin
z_sol = Evolutionary.optimize(
    cost,
    () -> random_individual(n2, k2),
    GA(; populationSize=10000, crossover=crossover_tpp, mutation=mutate_tpp, epsilon=0.01, crossoverRate=0.9),
    Evolutionary.Options(; iterations=10000)
)
end

println(has_subtour(z_sol.minimizer, n2))
println(z_sol)
# Out:
# false
#
#  * Status: success
#
#  * Candidate solution
#     Minimizer:  [49, 14, 30,  ...]
#     Minimum:    5551.058997016044
#     Iterations: 69
#
#  * Found with
#     Algorithm: GA[P=10000,x=0.9,μ=0.1,ɛ=0.01]
#
#  * Convergence measures
#     |f(x) - f(x')| = 0.0 ≤ 1.0e-12
#
#  * Work counters
#     Seconds run:   14.195 (vs limit Inf)
#     Iterations:    69
#     f(x) calls:    700000

# %%
push!(sol_50_50, (z_sol.minimum, opt_time))
info_items(z_sol.minimizer[n2 + 1:n2 + k2])
plot_tour(X, Y, z_sol.minimizer[1:n2])
# Out:
# Item 1 is bought in city 1
# Item 2 is bought in city 37
# Item 3 is bought in city 38
# Item 4 is bought in city 13
# Item 5 is bought in city 50
# Item 6 is bought in city 11
# Item 7 is bought in city 37
# Item 8 is bought in city 21
# Item 9 is bought in city 42
# Item 10 is bought in city 11
# Item 11 is bought in city 8
# Item 12 is bought in city 32
# Item 13 is bought in city 35
# Item 14 is bought in city 1
# Item 15 is bought in city 11
# Item 16 is bought in city 44
# Item 17 is bought in city 24
# Item 18 is bought in city 13
# Item 19 is bought in city 10
# Item 20 is bought in city 37
# Item 21 is bought in city 42
# Item 22 is bought in city 33
# Item 23 is bought in city 43
# Item 24 is bought in city 43
# Item 25 is bought in city 6
# Item 26 is bought in city 29
# Item 27 is bought in city 25
# Item 28 is bought in city 34
# Item 29 is bought in city 15
# Item 30 is bought in city 17
# Item 31 is bought in city 50
# Item 32 is bought in city 15
# Item 33 is bought in city 38
# Item 34 is bought in city 39
# Item 35 is bought in city 23
# Item 36 is bought in city 11
# Item 37 is bought in city 8
# Item 38 is bought in city 39
# Item 39 is bought in city 3
# Item 40 is bought in city 38
# Item 41 is bought in city 36
# Item 42 is bought in city 25
# Item 43 is bought in city 50
# Item 44 is bought in city 25
# Item 45 is bought in city 7
# Item 46 is bought in city 43
# Item 47 is bought in city 31
# Item 48 is bought in city 36
# Item 49 is bought in city 13
# Item 50 is bought in city 22

# %%
X, Y, d, cost_item_city = generate_random_tpp(n2, k2, random_seed=6)

# solution is vector of visited cities and cities where item was bought so length(z) = n + k
opt_time = @elapsed begin
z_sol = Evolutionary.optimize(
    cost,
    () -> random_individual(n2, k2),
    GA(; populationSize=10000, crossover=crossover_tpp, mutation=mutate_tpp, epsilon=0.01, crossoverRate=0.9),
    Evolutionary.Options(; iterations=10000)
)
end

println(has_subtour(z_sol.minimizer, n2))
println(z_sol)
# Out:
# false
#
#  * Status: success
#
#  * Candidate solution
#     Minimizer:  [10, 13, 48,  ...]
#     Minimum:    5764.077834684394
#     Iterations: 65
#
#  * Found with
#     Algorithm: GA[P=10000,x=0.9,μ=0.1,ɛ=0.01]
#
#  * Convergence measures
#     |f(x) - f(x')| = 0.0 ≤ 1.0e-12
#
#  * Work counters
#     Seconds run:   15.596 (vs limit Inf)
#     Iterations:    65
#     f(x) calls:    660000

# %%
push!(sol_50_50, (z_sol.minimum, opt_time))
info_items(z_sol.minimizer[n2 + 1:n2 + k2])
plot_tour(X, Y, z_sol.minimizer[1:n2])
# Out:
# Item 1 is bought in city 43
# Item 2 is bought in city 29
# Item 3 is bought in city 22
# Item 4 is bought in city 41
# Item 5 is bought in city 49
# Item 6 is bought in city 44
# Item 7 is bought in city 46
# Item 8 is bought in city 21
# Item 9 is bought in city 49
# Item 10 is bought in city 5
# Item 11 is bought in city 7
# Item 12 is bought in city 33
# Item 13 is bought in city 16
# Item 14 is bought in city 24
# Item 15 is bought in city 31
# Item 16 is bought in city 32
# Item 17 is bought in city 30
# Item 18 is bought in city 21
# Item 19 is bought in city 32
# Item 20 is bought in city 6
# Item 21 is bought in city 18
# Item 22 is bought in city 43
# Item 23 is bought in city 36
# Item 24 is bought in city 36
# Item 25 is bought in city 34
# Item 26 is bought in city 21
# Item 27 is bought in city 44
# Item 28 is bought in city 18
# Item 29 is bought in city 34
# Item 30 is bought in city 42
# Item 31 is bought in city 50
# Item 32 is bought in city 19
# Item 33 is bought in city 18
# Item 34 is bought in city 32
# Item 35 is bought in city 5
# Item 36 is bought in city 22
# Item 37 is bought in city 42
# Item 38 is bought in city 20
# Item 39 is bought in city 29
# Item 40 is bought in city 20
# Item 41 is bought in city 15
# Item 42 is bought in city 24
# Item 43 is bought in city 41
# Item 44 is bought in city 14
# Item 45 is bought in city 39
# Item 46 is bought in city 19
# Item 47 is bought in city 47
# Item 48 is bought in city 27
# Item 49 is bought in city 35
# Item 50 is bought in city 10

# %%
X, Y, d, cost_item_city = generate_random_tpp(n3, k3, random_seed=7)

# solution is vector of visited cities and cities where item was bought so length(z) = n + k
opt_time = @elapsed begin
z_sol = Evolutionary.optimize(
    cost,
    () -> random_individual(n3, k3),
    GA(; populationSize=10000, crossover=crossover_tpp, mutation=mutate_tpp, epsilon=0.01, crossoverRate=0.9),
    Evolutionary.Options(; iterations=10000)
)
end

println(has_subtour(z_sol.minimizer, n3))
println(z_sol)
# Out:
# false
#
#  * Status: success
#
#  * Candidate solution
#     Minimizer:  [49, 84, 60,  ...]
#     Minimum:    12436.241884974874
#     Iterations: 74
#
#  * Found with
#     Algorithm: GA[P=10000,x=0.9,μ=0.1,ɛ=0.01]
#
#  * Convergence measures
#     |f(x) - f(x')| = 0.0 ≤ 1.0e-12
#
#  * Work counters
#     Seconds run:   36.015 (vs limit Inf)
#     Iterations:    74
#     f(x) calls:    750000

# %%
push!(sol_100_100, (z_sol.minimum, opt_time))
info_items(z_sol.minimizer[n3 + 1:n3 + k3])
plot_tour(X, Y, z_sol.minimizer[1:n3])
# Out:
# Item 1 is bought in city 36
# Item 2 is bought in city 19
# Item 3 is bought in city 69
# Item 4 is bought in city 23
# Item 5 is bought in city 78
# Item 6 is bought in city 4
# Item 7 is bought in city 31
# Item 8 is bought in city 93
# Item 9 is bought in city 38
# Item 10 is bought in city 85
# Item 11 is bought in city 40
# Item 12 is bought in city 57
# Item 13 is bought in city 20
# Item 14 is bought in city 39
# Item 15 is bought in city 23
# Item 16 is bought in city 34
# Item 17 is bought in city 69
# Item 18 is bought in city 74
# Item 19 is bought in city 91
# Item 20 is bought in city 24
# Item 21 is bought in city 35
# Item 22 is bought in city 95
# Item 23 is bought in city 83
# Item 24 is bought in city 64
# Item 25 is bought in city 60
# Item 26 is bought in city 2
# Item 27 is bought in city 16
# Item 28 is bought in city 14
# Item 29 is bought in city 25
# Item 30 is bought in city 60
# Item 31 is bought in city 26
# Item 32 is bought in city 6
# Item 33 is bought in city 86
# Item 34 is bought in city 5
# Item 35 is bought in city 62
# Item 36 is bought in city 61
# Item 37 is bought in city 82
# Item 38 is bought in city 79
# Item 39 is bought in city 36
# Item 40 is bought in city 100
# Item 41 is bought in city 6
# Item 42 is bought in city 2
# Item 43 is bought in city 28
# Item 44 is bought in city 35
# Item 45 is bought in city 16
# Item 46 is bought in city 44
# Item 47 is bought in city 70
# Item 48 is bought in city 86
# Item 49 is bought in city 53
# Item 50 is bought in city 26
# Item 51 is bought in city 69
# Item 52 is bought in city 29
# Item 53 is bought in city 66
# Item 54 is bought in city 71
# Item 55 is bought in city 3
# Item 56 is bought in city 71
# Item 57 is bought in city 25
# Item 58 is bought in city 31
# Item 59 is bought in city 56
# Item 60 is bought in city 10
# Item 61 is bought in city 2
# Item 62 is bought in city 77
# Item 63 is bought in city 34
# Item 64 is bought in city 3
# Item 65 is bought in city 61
# Item 66 is bought in city 29
# Item 67 is bought in city 6
# Item 68 is bought in city 14
# Item 69 is bought in city 30
# Item 70 is bought in city 61
# Item 71 is bought in city 11
# Item 72 is bought in city 62
# Item 73 is bought in city 59
# Item 74 is bought in city 11
# Item 75 is bought in city 92
# Item 76 is bought in city 16
# Item 77 is bought in city 2
# Item 78 is bought in city 69
# Item 79 is bought in city 19
# Item 80 is bought in city 2
# Item 81 is bought in city 81
# Item 82 is bought in city 71
# Item 83 is bought in city 57
# Item 84 is bought in city 45
# Item 85 is bought in city 5
# Item 86 is bought in city 77
# Item 87 is bought in city 56
# Item 88 is bought in city 71
# Item 89 is bought in city 62
# Item 90 is bought in city 50
# Item 91 is bought in city 39
# Item 92 is bought in city 54
# Item 93 is bought in city 42
# Item 94 is bought in city 78
# Item 95 is bought in city 18
# Item 96 is bought in city 45
# Item 97 is bought in city 74
# Item 98 is bought in city 58
# Item 99 is bought in city 37
# Item 100 is bought in city 21

# %%
X, Y, d, cost_item_city = generate_random_tpp(n3, k3, random_seed=8)

# solution is vector of visited cities and cities where item was bought so length(z) = n + k
opt_time = @elapsed begin
z_sol = Evolutionary.optimize(
    cost,
    () -> random_individual(n3, k3),
    GA(; populationSize=10000, crossover=crossover_tpp, mutation=mutate_tpp, epsilon=0.01, crossoverRate=0.9),
    Evolutionary.Options(; iterations=10000)
)
end

println(has_subtour(z_sol.minimizer, n3))
println(z_sol)
# Out:
# false
#
#  * Status: success
#
#  * Candidate solution
#     Minimizer:  [61, 18, 52,  ...]
#     Minimum:    12247.410497384171
#     Iterations: 119
#
#  * Found with
#     Algorithm: GA[P=10000,x=0.9,μ=0.1,ɛ=0.01]
#
#  * Convergence measures
#     |f(x) - f(x')| = 0.0 ≤ 1.0e-12
#
#  * Work counters
#     Seconds run:   58.588 (vs limit Inf)
#     Iterations:    119
#     f(x) calls:    1200000

# %%
push!(sol_100_100, (z_sol.minimum, opt_time))
info_items(z_sol.minimizer[n3 + 1:n3 + k3])
plot_tour(X, Y, z_sol.minimizer[1:n3])
# Out:
# Item 1 is bought in city 7
# Item 2 is bought in city 31
# Item 3 is bought in city 6
# Item 4 is bought in city 89
# Item 5 is bought in city 65
# Item 6 is bought in city 50
# Item 7 is bought in city 60
# Item 8 is bought in city 38
# Item 9 is bought in city 51
# Item 10 is bought in city 64
# Item 11 is bought in city 36
# Item 12 is bought in city 2
# Item 13 is bought in city 15
# Item 14 is bought in city 1
# Item 15 is bought in city 44
# Item 16 is bought in city 41
# Item 17 is bought in city 25
# Item 18 is bought in city 56
# Item 19 is bought in city 94
# Item 20 is bought in city 57
# Item 21 is bought in city 84
# Item 22 is bought in city 24
# Item 23 is bought in city 96
# Item 24 is bought in city 18
# Item 25 is bought in city 54
# Item 26 is bought in city 66
# Item 27 is bought in city 12
# Item 28 is bought in city 62
# Item 29 is bought in city 100
# Item 30 is bought in city 46
# Item 31 is bought in city 63
# Item 32 is bought in city 72
# Item 33 is bought in city 71
# Item 34 is bought in city 78
# Item 35 is bought in city 83
# Item 36 is bought in city 33
# Item 37 is bought in city 65
# Item 38 is bought in city 65
# Item 39 is bought in city 99
# Item 40 is bought in city 10
# Item 41 is bought in city 70
# Item 42 is bought in city 21
# Item 43 is bought in city 40
# Item 44 is bought in city 85
# Item 45 is bought in city 71
# Item 46 is bought in city 37
# Item 47 is bought in city 46
# Item 48 is bought in city 62
# Item 49 is bought in city 28
# Item 50 is bought in city 37
# Item 51 is bought in city 88
# Item 52 is bought in city 54
# Item 53 is bought in city 85
# Item 54 is bought in city 25
# Item 55 is bought in city 53
# Item 56 is bought in city 41
# Item 57 is bought in city 67
# Item 58 is bought in city 24
# Item 59 is bought in city 9
# Item 60 is bought in city 23
# Item 61 is bought in city 1
# Item 62 is bought in city 36
# Item 63 is bought in city 72
# Item 64 is bought in city 37
# Item 65 is bought in city 72
# Item 66 is bought in city 46
# Item 67 is bought in city 12
# Item 68 is bought in city 1
# Item 69 is bought in city 64
# Item 70 is bought in city 83
# Item 71 is bought in city 98
# Item 72 is bought in city 42
# Item 73 is bought in city 60
# Item 74 is bought in city 2
# Item 75 is bought in city 16
# Item 76 is bought in city 54
# Item 77 is bought in city 30
# Item 78 is bought in city 73
# Item 79 is bought in city 50
# Item 80 is bought in city 12
# Item 81 is bought in city 8
# Item 82 is bought in city 30
# Item 83 is bought in city 13
# Item 84 is bought in city 75
# Item 85 is bought in city 68
# Item 86 is bought in city 43
# Item 87 is bought in city 74
# Item 88 is bought in city 19
# Item 89 is bought in city 26
# Item 90 is bought in city 22
# Item 91 is bought in city 27
# Item 92 is bought in city 24
# Item 93 is bought in city 84
# Item 94 is bought in city 3
# Item 95 is bought in city 46
# Item 96 is bought in city 84
# Item 97 is bought in city 26
# Item 98 is bought in city 99
# Item 99 is bought in city 9
# Item 100 is bought in city 81

# %%
X, Y, d, cost_item_city = generate_random_tpp(n3, k3, random_seed=9)

# solution is vector of visited cities and cities where item was bought so length(z) = n + k
opt_time = @elapsed begin
z_sol = Evolutionary.optimize(
    cost,
    () -> random_individual(n3, k3),
    GA(; populationSize=10000, crossover=crossover_tpp, mutation=mutate_tpp, epsilon=0.01, crossoverRate=0.9),
    Evolutionary.Options(; iterations=10000)
)
end

println(has_subtour(z_sol.minimizer, n3))
println(z_sol)
# Out:
# false
#
#  * Status: success
#
#  * Candidate solution
#     Minimizer:  [30, 46, 14,  ...]
#     Minimum:    12380.48928488673
#     Iterations: 73
#
#  * Found with
#     Algorithm: GA[P=10000,x=0.9,μ=0.1,ɛ=0.01]
#
#  * Convergence measures
#     |f(x) - f(x')| = 0.0 ≤ 1.0e-12
#
#  * Work counters
#     Seconds run:   35.409 (vs limit Inf)
#     Iterations:    73
#     f(x) calls:    740000

# %%
push!(sol_100_100, (z_sol.minimum, opt_time))
info_items(z_sol.minimizer[n3 + 1:n3 + k3])
plot_tour(X, Y, z_sol.minimizer[1:n3])
# Out:
# Item 1 is bought in city 24
# Item 2 is bought in city 73
# Item 3 is bought in city 66
# Item 4 is bought in city 47
# Item 5 is bought in city 78
# Item 6 is bought in city 82
# Item 7 is bought in city 83
# Item 8 is bought in city 10
# Item 9 is bought in city 6
# Item 10 is bought in city 79
# Item 11 is bought in city 84
# Item 12 is bought in city 27
# Item 13 is bought in city 86
# Item 14 is bought in city 73
# Item 15 is bought in city 83
# Item 16 is bought in city 59
# Item 17 is bought in city 85
# Item 18 is bought in city 83
# Item 19 is bought in city 88
# Item 20 is bought in city 54
# Item 21 is bought in city 44
# Item 22 is bought in city 70
# Item 23 is bought in city 24
# Item 24 is bought in city 35
# Item 25 is bought in city 61
# Item 26 is bought in city 25
# Item 27 is bought in city 75
# Item 28 is bought in city 37
# Item 29 is bought in city 44
# Item 30 is bought in city 52
# Item 31 is bought in city 100
# Item 32 is bought in city 69
# Item 33 is bought in city 96
# Item 34 is bought in city 12
# Item 35 is bought in city 66
# Item 36 is bought in city 19
# Item 37 is bought in city 77
# Item 38 is bought in city 90
# Item 39 is bought in city 53
# Item 40 is bought in city 58
# Item 41 is bought in city 47
# Item 42 is bought in city 33
# Item 43 is bought in city 53
# Item 44 is bought in city 33
# Item 45 is bought in city 49
# Item 46 is bought in city 61
# Item 47 is bought in city 30
# Item 48 is bought in city 68
# Item 49 is bought in city 41
# Item 50 is bought in city 81
# Item 51 is bought in city 81
# Item 52 is bought in city 44
# Item 53 is bought in city 59
# Item 54 is bought in city 19
# Item 55 is bought in city 42
# Item 56 is bought in city 65
# Item 57 is bought in city 53
# Item 58 is bought in city 22
# Item 59 is bought in city 14
# Item 60 is bought in city 85
# Item 61 is bought in city 56
# Item 62 is bought in city 9
# Item 63 is bought in city 56
# Item 64 is bought in city 23
# Item 65 is bought in city 86
# Item 66 is bought in city 37
# Item 67 is bought in city 19
# Item 68 is bought in city 36
# Item 69 is bought in city 39
# Item 70 is bought in city 76
# Item 71 is bought in city 28
# Item 72 is bought in city 96
# Item 73 is bought in city 95
# Item 74 is bought in city 38
# Item 75 is bought in city 15
# Item 76 is bought in city 77
# Item 77 is bought in city 81
# Item 78 is bought in city 90
# Item 79 is bought in city 28
# Item 80 is bought in city 52
# Item 81 is bought in city 94
# Item 82 is bought in city 50
# Item 83 is bought in city 74
# Item 84 is bought in city 20
# Item 85 is bought in city 4
# Item 86 is bought in city 24
# Item 87 is bought in city 82
# Item 88 is bought in city 75
# Item 89 is bought in city 7
# Item 90 is bought in city 34
# Item 91 is bought in city 20
# Item 92 is bought in city 86
# Item 93 is bought in city 16
# Item 94 is bought in city 75
# Item 95 is bought in city 46
# Item 96 is bought in city 86
# Item 97 is bought in city 64
# Item 98 is bought in city 54
# Item 99 is bought in city 27
# Item 100 is bought in city 52

# %%
df = DataFrame(Iterative_method_50_20=results_50_20, 
    Iterative_method_50_50=results_50_50, 
    Iterative_method_100_100=results_100_100,
    Genetic_50_20=sol_50_20,
    Genetic_50_50=sol_50_50,
    Genetic_100_100=sol_100_100)
# Out:
# 3×6 DataFrame
#  Row │ Iterative_method_50_20  Iterative_method_50_50  Iterative_method_100_10 ⋯
#      │ Any                     Any                     Any                     ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ (1569.95, 0.0109999)    (3239.97, 0.322001)     (5860.38, 288.651)      ⋯
#    2 │ (1612.07, 0.692)        (3149.27, 2.821)        (5890.58, 10.962)
#    3 │ (1679.49, 0.0869999)    (3190.33, 3.154)        (5899.56, 16.42)
#                                                                4 columns omitted

# %% [markdown]
# # 4.4 PMX Crossover Implementation

# %%
function pmx_crossover(p1::Vector{Int}, p2::Vector{Int}; rng::AbstractRNG=Random.default_rng())
    n = length(p1)
    c1 = fill(-1, n)
    c2 = fill(-1, n)
    
    # Select two crossover points
    point1 = rand(rng, 1:(n-1))
    point2 = rand(rng, (point1+1):n)
    
    # Create the mapping between elements
    for i in point1:point2
        c1[i] = p2[i]
        c2[i] = p1[i]
    end

    map1 = Dict(p2[i] => p1[i] for i in point1:point2)
    map2 = Dict(p1[i] => p2[i] for i in point1:point2)
    
    # Fill in the elements between crossover points
    segment1 = Set(p2[point1:point2])
    segment2 = Set(p1[point1:point2])
    
    # Fix remaining elements
    for i in 1:n
        if i < point1 || i > point2
            val1 = p1[i]
            while val1 in segment1
                val1 = map1[val1]
            end
            c1[i] = val1

            val2 = p2[i]
            while val2 in segment2
                val2 = map2[val2]
            end
            c2[i] = val2
        end
    end
    
    return c1, c2
end

function crossover_tpp_pmx(p1, p2; rng=Random.default_rng())
    n = length(unique(p1))  
    k = length(p1) - n     

    x1, y1 = decode_individual(p1, n, k)
    x2, y2 = decode_individual(p2, n, k)

    cx1, cx2 = pmx_crossover(x1, x2; rng=rng)
    cy = rand(rng, Bool) ? y1 : y2

    return encode_individual(cx1, cy), encode_individual(cx2, cy)
end
# Out:
# crossover_tpp_pmx (generic function with 1 method)

# %% [markdown]
# # 4.5 PMX Crossover Performance Comparison

# %%
using Statistics

sol_pmx_50_20 = []
sol_pmx_50_50 = []
sol_pmx_100_100 = []

# Test for n=50, k=20
X, Y, d, cost_item_city = generate_random_tpp(50, 20, random_seed=1)
opt_time = @elapsed begin
    z_sol = Evolutionary.optimize(
        cost,
        () -> random_individual(50, 20),
        GA(; populationSize=200, crossover=crossover_tpp_pmx, mutation=mutate_tpp, epsilon=0.01, crossoverRate=0.9),
        Evolutionary.Options(; iterations=1000)
    )
end
push!(sol_pmx_50_20, (z_sol.minimum, opt_time))
info_items(z_sol.minimizer[51:70])
plot_tour(X, Y, z_sol.minimizer[1:50])
# Out:
# Item 1 is bought in city 40
# Item 2 is bought in city 18
# Item 3 is bought in city 37
# Item 4 is bought in city 29
# Item 5 is bought in city 2
# Item 6 is bought in city 40
# Item 7 is bought in city 49
# Item 8 is bought in city 34
# Item 9 is bought in city 1
# Item 10 is bought in city 45
# Item 11 is bought in city 48
# Item 12 is bought in city 17
# Item 13 is bought in city 11
# Item 14 is bought in city 20
# Item 15 is bought in city 44
# Item 16 is bought in city 35
# Item 17 is bought in city 5
# Item 18 is bought in city 16
# Item 19 is bought in city 8
# Item 20 is bought in city 29

# %%
# Test for n=50, k=50
X, Y, d, cost_item_city = generate_random_tpp(50, 50, random_seed=1)
opt_time = @elapsed begin
    z_sol = Evolutionary.optimize(
        cost,
        () -> random_individual(50, 50),
        GA(; populationSize=200, crossover=crossover_tpp_pmx, mutation=mutate_tpp, epsilon=0.01, crossoverRate=0.9),
        Evolutionary.Options(; iterations=1000)
    )
end
push!(sol_pmx_50_50, (z_sol.minimum, opt_time))
info_items(z_sol.minimizer[51:100])
plot_tour(X, Y, z_sol.minimizer[1:50])
# Out:
# Item 1 is bought in city 19
# Item 2 is bought in city 2
# Item 3 is bought in city 9
# Item 4 is bought in city 12
# Item 5 is bought in city 50
# Item 6 is bought in city 41
# Item 7 is bought in city 7
# Item 8 is bought in city 29
# Item 9 is bought in city 19
# Item 10 is bought in city 43
# Item 11 is bought in city 8
# Item 12 is bought in city 32
# Item 13 is bought in city 14
# Item 14 is bought in city 36
# Item 15 is bought in city 19
# Item 16 is bought in city 2
# Item 17 is bought in city 16
# Item 18 is bought in city 12
# Item 19 is bought in city 3
# Item 20 is bought in city 32
# Item 21 is bought in city 5
# Item 22 is bought in city 38
# Item 23 is bought in city 16
# Item 24 is bought in city 33
# Item 25 is bought in city 47
# Item 26 is bought in city 31
# Item 27 is bought in city 32
# Item 28 is bought in city 33
# Item 29 is bought in city 14
# Item 30 is bought in city 34
# Item 31 is bought in city 47
# Item 32 is bought in city 6
# Item 33 is bought in city 2
# Item 34 is bought in city 40
# Item 35 is bought in city 40
# Item 36 is bought in city 47
# Item 37 is bought in city 21
# Item 38 is bought in city 4
# Item 39 is bought in city 4
# Item 40 is bought in city 7
# Item 41 is bought in city 43
# Item 42 is bought in city 15
# Item 43 is bought in city 17
# Item 44 is bought in city 8
# Item 45 is bought in city 35
# Item 46 is bought in city 19
# Item 47 is bought in city 40
# Item 48 is bought in city 32
# Item 49 is bought in city 7
# Item 50 is bought in city 9

# %%
# Test for n=100, k=100
X, Y, d, cost_item_city = generate_random_tpp(100, 100, random_seed=1)
opt_time = @elapsed begin
    z_sol = Evolutionary.optimize(
        cost,
        () -> random_individual(100, 100),
        GA(; populationSize=200, crossover=crossover_tpp_pmx, mutation=mutate_tpp, epsilon=0.01, crossoverRate=0.9),
        Evolutionary.Options(; iterations=1000)
    )
end
push!(sol_pmx_100_100, (z_sol.minimum, opt_time))
info_items(z_sol.minimizer[101:200])
plot_tour(X, Y, z_sol.minimizer[1:100])
# Out:
# Item 1 is bought in city 74
# Item 2 is bought in city 9
# Item 3 is bought in city 97
# Item 4 is bought in city 2
# Item 5 is bought in city 24
# Item 6 is bought in city 52
# Item 7 is bought in city 27
# Item 8 is bought in city 69
# Item 9 is bought in city 47
# Item 10 is bought in city 15
# Item 11 is bought in city 54
# Item 12 is bought in city 71
# Item 13 is bought in city 79
# Item 14 is bought in city 49
# Item 15 is bought in city 2
# Item 16 is bought in city 29
# Item 17 is bought in city 24
# Item 18 is bought in city 35
# Item 19 is bought in city 61
# Item 20 is bought in city 90
# Item 21 is bought in city 100
# Item 22 is bought in city 58
# Item 23 is bought in city 61
# Item 24 is bought in city 18
# Item 25 is bought in city 87
# Item 26 is bought in city 20
# Item 27 is bought in city 95
# Item 28 is bought in city 10
# Item 29 is bought in city 100
# Item 30 is bought in city 20
# Item 31 is bought in city 4
# Item 32 is bought in city 27
# Item 33 is bought in city 14
# Item 34 is bought in city 86
# Item 35 is bought in city 33
# Item 36 is bought in city 99
# Item 37 is bought in city 4
# Item 38 is bought in city 32
# Item 39 is bought in city 86
# Item 40 is bought in city 11
# Item 41 is bought in city 1
# Item 42 is bought in city 85
# Item 43 is bought in city 37
# Item 44 is bought in city 32
# Item 45 is bought in city 77
# Item 46 is bought in city 43
# Item 47 is bought in city 10
# Item 48 is bought in city 51
# Item 49 is bought in city 79
# Item 50 is bought in city 42
# Item 51 is bought in city 98
# Item 52 is bought in city 83
# Item 53 is bought in city 3
# Item 54 is bought in city 18
# Item 55 is bought in city 69
# Item 56 is bought in city 57
# Item 57 is bought in city 39
# Item 58 is bought in city 9
# Item 59 is bought in city 46
# Item 60 is bought in city 93
# Item 61 is bought in city 29
# Item 62 is bought in city 12
# Item 63 is bought in city 25
# Item 64 is bought in city 2
# Item 65 is bought in city 46
# Item 66 is bought in city 20
# Item 67 is bought in city 99
# Item 68 is bought in city 15
# Item 69 is bought in city 12
# Item 70 is bought in city 86
# Item 71 is bought in city 31
# Item 72 is bought in city 75
# Item 73 is bought in city 33
# Item 74 is bought in city 95
# Item 75 is bought in city 25
# Item 76 is bought in city 93
# Item 77 is bought in city 96
# Item 78 is bought in city 56
# Item 79 is bought in city 59
# Item 80 is bought in city 33
# Item 81 is bought in city 61
# Item 82 is bought in city 75
# Item 83 is bought in city 77
# Item 84 is bought in city 1
# Item 85 is bought in city 47
# Item 86 is bought in city 32
# Item 87 is bought in city 67
# Item 88 is bought in city 48
# Item 89 is bought in city 52
# Item 90 is bought in city 7
# Item 91 is bought in city 38
# Item 92 is bought in city 69
# Item 93 is bought in city 56
# Item 94 is bought in city 74
# Item 95 is bought in city 21
# Item 96 is bought in city 18
# Item 97 is bought in city 9
# Item 98 is bought in city 20
# Item 99 is bought in city 26
# Item 100 is bought in city 71

# %%
# Compare results
df_comparison = DataFrame(
    Size = ["50,20", "50,50", "100,100"],
    Inversion_Mean_Cost = [mean([x[1] for x in sol_50_20]), mean([x[1] for x in sol_50_50]), mean([x[1] for x in sol_100_100])],
    Inversion_Mean_Time = [mean([x[2] for x in sol_50_20]), mean([x[2] for x in sol_50_50]), mean([x[2] for x in sol_100_100])],
    PMX_Mean_Cost = [mean([x[1] for x in sol_pmx_50_20]), mean([x[1] for x in sol_pmx_50_50]), mean([x[1] for x in sol_pmx_100_100])],
    PMX_Mean_Time = [mean([x[2] for x in sol_pmx_50_20]), mean([x[2] for x in sol_pmx_50_50]), mean([x[2] for x in sol_pmx_100_100])]
)
# Out:
# 3×5 DataFrame
#  Row │ Size     Inversion_Mean_Cost  Inversion_Mean_Time  PMX_Mean_Cost  PMX_M ⋯
#      │ String   Float64              Float64              Float64        Float ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 50,20                2940.52              10.6554        3151.71        ⋯
#    2 │ 50,50                5767.14              15.7401        6283.75
#    3 │ 100,100             12354.7               43.5536       13154.1
#                                                                 1 column omitted

# %% [markdown]
# # 4.6 Tpp - essential cities

# %%
function build_tpp_essential_cities_model(d, cost_item_city, n, k)
    model = Model(GLPK.Optimizer)
    @variable(model, x[1:n, 1:n], Bin, Symmetric)
    @variable(model, y[1:k, 1:n], Bin) 
    @variable(model, visited[1:n], Bin) # added visited variable visited[i] = 1 if city visited else visited[i] = 0
    @objective(model, Min, sum(d .* x) / 2 + sum(cost_item_city .* y))
    @constraint(model, [j in 1:n], sum(y[:, j]) <= k * visited[j]) # you have to visit city in order to buy item
    @constraint(model, [j in 1:n], sum(x[j, :]) == 2 * visited[j]) # visited city has 2 edges
    @constraint(model, [i in 1:n], x[i, i] == 0)
    @constraint(model, [i in 1:k], sum(y[i, :]) == 1) 
    return model
end

function subtour(edges::Vector{Tuple{Int,Int}}, n)
    shortest_subtour, unvisited = collect(1:n), Set(collect(1:n))
    while !isempty(unvisited)
        this_cycle, neighbors = Int[], unvisited
        while !isempty(neighbors)
            current = pop!(neighbors)
            push!(this_cycle, current)
            if length(this_cycle) > 1
                pop!(unvisited, current)
            end
            neighbors =
                [j for (i, j) in edges if i == current && j in unvisited]
        end
        if length(this_cycle) < length(shortest_subtour)
            shortest_subtour = this_cycle
        end
    end
    return shortest_subtour
end

function selected_edges(x::Matrix{Float64}, n)
    return Tuple{Int,Int}[(i, j) for i in 1:n, j in 1:n if x[i, j] > 0.5]
end

function bought_items(y::Matrix{Float64}, n, k)
    return sort(Tuple{Int,Int}[(i, j) for i in 1:k, j in 1:n if y[i, j] > 0.5], by = first)
end

subtour(x::Matrix{Float64}) = subtour(selected_edges(x, size(x, 1)), size(x, 1))
subtour(x::AbstractMatrix{VariableRef}) = subtour(value.(x))

function solve_tpp_essential_cities(X, Y, d, cost_item_city, n, k)
    iterative_model = build_tpp_essential_cities_model(d, cost_item_city, n, k)
    optimize!(iterative_model)
    @assert is_solved_and_feasible(iterative_model)
    time_iterated = solve_time(iterative_model)
    cycle = subtour(iterative_model[:x])
    while 1 < length(cycle) < sum(value.(iterative_model[:visited]))
        # println("Found cycle of length $(length(cycle))")
        S = [(i, j) for (i, j) in Iterators.product(cycle, cycle) if i < j]
        @constraint(
            iterative_model,
            sum(iterative_model[:x][i, j] for (i, j) in S) <= length(cycle) - 1,
        )
        optimize!(iterative_model)
        @assert is_solved_and_feasible(iterative_model)
        time_iterated += solve_time(iterative_model)
        cycle = subtour(iterative_model[:x])
    end

    obj = objective_value(iterative_model)
    return iterative_model, obj, time_iterated, X, Y
end

function plot_tour(X, Y, x)
    plot = Plots.plot()
    Plots.scatter!(X, Y)
    for (i, j) in selected_edges(x, size(x, 1))
        Plots.plot!([X[i], X[j]], [Y[i], Y[j]]; legend = false)
    end
    return plot
end

function items_info(y::Matrix{Float64}, n, k)
    for (i, j) in bought_items(y, n, k)
        println("Item $i is bought in city $j")
    end
end
# Out:
# items_info (generic function with 1 method)

# %%
X, Y, d, cost_item_city = generate_random_tpp(50, 20)
it_model, obj, time_iterated, X, Y = solve_tpp_essential_cities(X, Y, d, cost_item_city, 50, 20)
println(obj)
println(time_iterated)
items_info(JuMP.value.(it_model[:y]), 50, 20)
plot_tour(X, Y, JuMP.value.(it_model[:x]))
# Out:
# 1159.767402578683
# 194.4210000038147
# Item 1 is bought in city 28
# Item 2 is bought in city 4
# Item 3 is bought in city 28
# Item 4 is bought in city 44
# Item 5 is bought in city 11
# Item 6 is bought in city 45
# Item 7 is bought in city 37
# Item 8 is bought in city 13
# Item 9 is bought in city 44
# Item 10 is bought in city 34
# Item 11 is bought in city 30
# Item 12 is bought in city 34
# Item 13 is bought in city 45
# Item 14 is bought in city 44
# Item 15 is bought in city 44
# Item 16 is bought in city 29
# Item 17 is bought in city 47
# Item 18 is bought in city 40
# Item 19 is bought in city 5
# Item 20 is bought in city 11

# %% [markdown]
# # 4.7 lazy constraints

# %%
X, Y, d, cost_item_city = generate_random_tpp(n1, k1)
lazy_model = build_tpp_model(d, cost_item_city, n1, k1)
function subtour_elimination_callback(cb_data)
    status = callback_node_status(cb_data, lazy_model)
    if status != MOI.CALLBACK_NODE_STATUS_INTEGER
        return  # Only run at integer solutions
    end
    cycle = subtour(callback_value.(cb_data, lazy_model[:x]))
    if !(1 < length(cycle) < n1)
        return  # Only add a constraint if there is a cycle
    end
    println("Found cycle of length $(length(cycle))")
    S = [(i, j) for (i, j) in Iterators.product(cycle, cycle) if i < j]
    con = @build_constraint(
        sum(lazy_model[:x][i, j] for (i, j) in S) <= length(cycle) - 1,
    )
    MOI.submit(lazy_model, MOI.LazyConstraint(cb_data), con)
    return
end
set_attribute(
    lazy_model,
    MOI.LazyConstraintCallback(),
    subtour_elimination_callback,
)
optimize!(lazy_model)
@assert is_solved_and_feasible(lazy_model)
objective_value(lazy_model)
# Out:
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 6
# Found cycle of length 3
# Found cycle of length 6
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 6
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 7
# Found cycle of length 16
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 4
# Found cycle of length 8
# Found cycle of length 4
# Found cycle of length 12
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 6
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 6
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 6
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 6
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 6
# Found cycle of length 7
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 6
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 7
# Found cycle of length 5
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 6
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 6
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 6
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 6
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 6
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 7
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 5
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 5
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 6
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 6
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 4
# ...
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 6
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 4
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 5
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 7
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 4
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3
# Found cycle of length 3

# %%
plot_tour(X, Y, value.(lazy_model[:x]))
